# %% [markdown]
# ## Scrape info box of Toy story

# %% [markdown]
# ## Scrape info box of every Disney movie

# %%
from bs4 import BeautifulSoup as bs
import requests
import json
# python -m pip install "pymongo[srv]"==3.11

# %%
import re

def clean_tag(soup: bs):
    for tag in soup.find_all(['sup', 'b', 'span', 'br']):
        tag.decompose()


def clean_parenthesis(text: str) -> str:
    pattern = r'\s*\([^)]*\)'
    cleaned_text = re.sub(pattern, '', text)
    return cleaned_text      

        
def scrape_info_box(url: str) -> dict:
    movie_info = {}
    r = requests.get(url)
    soup = bs(r.content, 'html.parser')
    info_box = soup.find(class_='infobox vevent')

    movie_info['Title'] = info_box.find(class_='infobox-above').string
    movie_info['Poster'] = 'https:' + info_box.find(class_='infobox-image').find('img')['src']
    clean_tag(info_box)
    theads = info_box.find_all('th', {'class': 'infobox-label'})
    tdata = info_box.find_all('td', {'class': 'infobox-data'})

    for label, data in zip(theads, tdata):
        label_text = label.get_text(' ', strip=True).replace('\xa0', ' ')

        if label_text == 'Directed by':
           clean_tag(data)
           movie_info[label_text] = [re.sub(r'\s*\(.*?\)\s*', '', a['title']) for a in data.find_all("a")]
           movie_info['Directors url'] = [a['href'] for a in data.find_all("a")]
        elif label_text == 'Based on':
            data_text = data.get_text(' ', strip=True).replace('\xa0', ' ')
            movie_info[label_text] = clean_parenthesis(data_text)
        elif label_text == 'Distributed by':
            data_text = data.get_text(' ', strip=True).replace('\xa0', ' ')
            movie_info[label_text] = clean_parenthesis(data_text)
        elif label_text == 'Release dates':
            data_text = data.get_text('-', strip=True).replace('\xa0', ' ')
            movie_info[label_text] = data_text.split('-')[0]
        else:
            movie_info[label_text] = clean_parenthesis(data.get_text(', ', strip=True).replace('\xa0', ' '))
        
    return  movie_info

# https://en.wikipedia.org/wiki/The_Reluctant_Dragon_(1941_film)

# %%
print(scrape_info_box('https://en.wikipedia.org/wiki/The_Reluctant_Dragon_(1941_film)'))
# Out:
# {'Title': 'The Reluctant Dragon', 'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/fe/Reluctant_Dragon.jpg/220px-Reluctant_Dragon.jpg', 'Directed by': ['Alfred Werker', 'Hamilton Luske', 'Jack Cutting', 'Ub Iwerks', 'Jack Kinney'], 'Directors url': ['/wiki/Alfred_Werker', '/wiki/Hamilton_Luske', '/wiki/Jack_Cutting_(animator)', '/wiki/Ub_Iwerks', '/wiki/Jack_Kinney'], 'Written by': 'Live-action:, Ted Sears, Al Perkins, Larry Clemmons, Bill Cottrell, Harry Clork, Robert Benchley, The Reluctant Dragon, segment:, Kenneth Grahame,, Erdman Penner, T. Hee, Baby Weems, segment:, Joe Grant, Dick Huemer, John Miller', 'Produced by': 'Walt Disney', 'Starring': 'Robert Benchley, Frances Gifford, Buddy Pepper, Nana Bryant', 'Cinematography': 'Bert Glennon', 'Edited by': 'Paul Weatherwax', 'Music by': 'Frank Churchill, Larry Morey', 'Production company': 'Walt Disney Productions', 'Distributed by': 'RKO Radio Pictures', 'Release date': 'June 27, 1941', 'Running time': '74 minutes', 'Country': 'United States', 'Language': 'English', 'Budget': '$600,000', 'Box office': '$960,000'}

# %%
response = requests.get('https://en.wikipedia.org/wiki/List_of_Walt_Disney_Pictures_films')
soup = bs(response.content)
eras = soup.find_all('h3')
# era_tables = soup.find_all('table', attrs={'class':'wikitable sortable'})
# movies = soup.select('.wikitable.sortable i')

base_path = 'https://en.wikipedia.org'
movie_info_list = []
for era in eras[:-2]:
    table = era.find_next_sibling('table', class_='wikitable sortable')
    for movie in table.select('i'):
        try:
            print(f"Scraping info of movie {movie.a['title']}")
            full_path = base_path +  movie.a['href']
            movie_info_list.append(scrape_info_box(full_path))
        except Exception as e:
            print(e)
# Out:
# Scraping info of movie Snow White and the Seven Dwarfs (1937 film)
# Scraping info of movie Pinocchio (1940 film)
# Scraping info of movie Fantasia (1940 film)
# Scraping info of movie The Reluctant Dragon (1941 film)
# Scraping info of movie Dumbo
# Scraping info of movie Bambi
# Scraping info of movie Saludos Amigos
# Scraping info of movie Victory Through Air Power (film)
# Scraping info of movie The Three Caballeros
# Scraping info of movie Make Mine Music
# Scraping info of movie Song of the South
# Scraping info of movie Fun and Fancy Free
# Scraping info of movie Melody Time
# Scraping info of movie So Dear to My Heart
# Scraping info of movie The Adventures of Ichabod and Mr. Toad
# Scraping info of movie Cinderella (1950 film)
# Scraping info of movie Treasure Island (1950 film)
# Scraping info of movie Alice in Wonderland (1951 film)
# Scraping info of movie The Story of Robin Hood (film)
# Scraping info of movie Peter Pan (1953 film)
# Scraping info of movie The Sword and the Rose
# Scraping info of movie The Living Desert
# Scraping info of movie Rob Roy: The Highland Rogue
# Scraping info of movie The Vanishing Prairie
# Scraping info of movie 20,000 Leagues Under the Sea (1954 film)
# Scraping info of movie Davy Crockett: King of the Wild Frontier (film)
# Scraping info of movie Lady and the Tramp
# Scraping info of movie The African Lion
# Scraping info of movie The Littlest Outlaw
# Scraping info of movie The Great Locomotive Chase
# Scraping info of movie Davy Crockett and the River Pirates
# Scraping info of movie Secrets of Life
# Scraping info of movie Westward Ho the Wagons!
# Scraping info of movie Johnny Tremain (film)
# Scraping info of movie Perri (film)
# Scraping info of movie Old Yeller (film)
# Scraping info of movie The Light in the Forest (film)
# Scraping info of movie White Wilderness (film)
# Scraping info of movie Tonka (film)
# Scraping info of movie Sleeping Beauty (1959 film)
# Scraping info of movie The Shaggy Dog (1959 film)
# Scraping info of movie Darby O'Gill and the Little People
# Scraping info of movie Third Man on the Mountain
# Scraping info of movie Toby Tyler or 10 Weeks with a Circus (film)
# Scraping info of movie Kidnapped (1960 film)
# Scraping info of movie Pollyanna (1960 film)
# Scraping info of movie Zorro (1957 TV series)
# 'NoneType' object has no attribute 'find'
# Scraping info of movie Jungle Cat (film)
# Scraping info of movie Ten Who Dared
# Scraping info of movie Swiss Family Robinson (1960 film)
# Scraping info of movie One Hundred and One Dalmatians
# Scraping info of movie The Absent-Minded Professor
# Scraping info of movie The Parent Trap (1961 film)
# Scraping info of movie Nikki: Wild Dog of the North
# Scraping info of movie Greyfriars Bobby (film)
# Scraping info of movie Babes in Toyland (1961 film)
# Scraping info of movie Moon Pilot
# Scraping info of movie Bon Voyage! (1962 film)
# Scraping info of movie Big Red (film)
# Scraping info of movie Almost Angels
# Scraping info of movie The Legend of Lobo
# Scraping info of movie In Search of the Castaways (film)
# Scraping info of movie The Ice Age Adventures of Buck Wild
# Scraping info of movie The Beatles: Get Back
# 'NoneType' object has no attribute 'find'
# Scraping info of movie Turning Red
# Scraping info of movie Cheaper by the Dozen (2022 film)
# Scraping info of movie Better Nate Than Ever (film)
# Scraping info of movie Polar Bear (film)
# Scraping info of movie Chip 'n Dale: Rescue Rangers (film)
# Scraping info of movie Hollywood Stargirl
# Scraping info of movie Lightyear (film)
# Scraping info of movie Rise (2022 film)
# Scraping info of movie Pinocchio (2022 live-action film)
# Scraping info of movie Hocus Pocus 2
# Scraping info of movie Disenchanted (film)
# Scraping info of movie Strange World (film)
# Scraping info of movie Diary of a Wimpy Kid: Rodrick Rules (2022 film)
# Scraping info of movie Night at the Museum: Kahmunrah Rises Again
# Scraping info of movie Chang Can Dunk
# Scraping info of movie Peter Pan & Wendy
# Scraping info of movie Crater (film)
# Scraping info of movie The Little Mermaid (2023 film)
# Scraping info of movie Elemental (2023 film)
# Scraping info of movie World's Best (film)
# Scraping info of movie Indiana Jones and the Dial of Destiny
# Scraping info of movie Haunted Mansion (2023 film)
# Scraping info of movie Dashing Through the Snow
# Scraping info of movie Wish (film)
# Scraping info of movie Diary of a Wimpy Kid Christmas: Cabin Fever

# %%
movie_info_list[-1]
# Out:
# {'Title': 'Diary of a Wimpy Kid Christmas: Cabin Fever',
#  'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c0/Diary_of_a_Wimpy_Kid_Christmas_Cabin_Fever_poster.jpg/220px-Diary_of_a_Wimpy_Kid_Christmas_Cabin_Fever_poster.jpg',
#  'Directed by': [],
#  'Directors url': [],
#  'Screenplay by': 'Jeff Kinney',
#  'Based on': 'Diary of a Wimpy Kid: Cabin Fever by Jeff Kinney',
#  'Produced by': 'Jeff Kinney',
#  'Starring': 'Wesley Kimmel, Spencer Howell, Erica Cerra, Hunter Dillon, Chris Diamantopoulos',
#  'Music by': 'John Paesano',
#  'Production companies': 'Walt Disney Pictures, Bardel Entertainment',
#  'Distributed by': 'Disney+',
#  'Release date': 'December 8, 2023',
#  'Running time': '62 minutes',
#  'Countries': 'United States, Canada',
#  'Language': 'English'}

# %% [markdown]
# ## Save and reload movie data

# %%
def save_json(title, data):
    with open(title, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)
        
def load_json(title):
    with open(title, encoding='utf-8') as f:
        return json.loads(f.read())

# %%
save_json('movies.json', movie_info_list)

# %%
movie_info_list = load_json('movies.json')

# %% [markdown]
# ### Get directors's info

# %%
def get_director_info(director:str, rel_url:str):
    director_info = {}
    base_url = "https://en.wikipedia.org"
    full_url = base_url + rel_url
    r = requests.get(full_url)
    soup = bs(r.content, 'html.parser')
    info_box = soup.find('table', {'class': 'biography'})

    print(director)
    director_info['Director Name'] = director   
    if info_box:
        theads = info_box.find_all('th', {'class': 'infobox-label'})
        tdata = info_box.find_all('td', {'class': 'infobox-data'})
        for label, data in zip(theads, tdata):
            label_text = label.get_text(' ', strip=True).replace('\xa0', ' ')
            if label_text == 'Born':
                director_info[label_text] = born.string if (born:= data.find('span', {'class': 'bday'})) else 'Unknown'
            elif label_text == "Occupations":
                director_info[label_text] = data.get_text(', ', strip=True).replace('\xa0', ' ')
            elif label_text == "Years active":
                director_info[label_text] = data.get_text(', ', strip=True).replace('\xa0', ' ')
            elif label_text == "Spouse":
                director_info[label_text] = data.get_text(', ', strip=True).replace('\xa0', ' ').split(', ')[0]
            elif label_text == "Awards":
                for tag in data.find_all(['i']):
                    tag.decompose()
                director_info[label_text] = data.get_text(', ', strip=True).replace('\xa0', ' ')
        
    else:
        director_info.update({key: 'Unknown' for key in ['Born', 'Died', 'Occupations', "Years active", "Spouse", "Awards"]})

    return director_info

director_info_list = []

director_url_set = {(director, url) for movie in movie_info_list for director, url in zip(movie.get('Directed by', []), movie.get('Directors url', []))}
# 316 unique        
print(len(director_url_set))

for director, url in director_url_set:
    director_info_list.append(get_director_info(director=director, rel_url=url))
# Out:
# 316
# George Butler
# Reginald Hudlin
# Brenda Chapman
# Craig Gillespie
# Brian Fee
# Donovan Cook
# Swinton O. Scott III
# Hamilton Luske
# Andy Knight
# Fletcher Markle
# Lasse Hallström
# Andrew Adamson
# Kenneth Branagh
# Gore Verbinski
# John Pasquin
# Chris Buck
# Rob Minkoff
# Gary Trousdale
# Josh Cooley
# Hayao Miyazaki
# Peter Sohn
# Robert Butler
# Paul and Gaëtan Brizzi
# Barry Cook
# Sara Sugarman
# Nitesh Tiwari
# Pete Docter
# Brian Henson
# Hiromasa Yonebayashi
# Rick Calabash
# Bob Spiers
# Charlie Bean
# Mark Waters
# Ford Beebe
# Nick Marck
# Bruce Bilson
# Don Chaffey
# Tim Hunter
# Nancy Meyers
# Tim Story
# Geoff Burrowes
# Robert Altman
# Timothy Björklund
# Victor Cook
# Andrew Davis
# Mira Nair
# Matthew O'Callaghan
# Bill Paxton
# Joe Camp
# Larry Morey
# Ron Underwood
# George Scribner
# Keith Scholey
# Jim Fall
# Rob Marshall
# James Neilson
# Ericson Core
# Steve Miner
# Julia Hart
# Lewis R. Foster
# Norm Ferguson
# Domee Shi
# Michael O'Herlihy
# Alfred Werker
# Steven Hilliard Stern
# Jugal Hansraj
# Ralph Zondag
# Stanley Tong
# Bruce Hendricks
# Russ Mayberry
# Fawn Veerasunthorn
# Gary Nelson
# Clyde Geronimi
# Duwayne Dunham
# N. Paul Kenworthy
# Bill Condon
# Arlene Sanford
# Tony Leondis
# Jared Bush
# Beyoncé
# David Mickey Evans
# John Lee Hancock
# Arthur Hiller
# Louis Schwartzberg
# Ralph Wright
# James Orr
# Matthew Robbins
# Bernard McEveety
# Jake Nava
# Tim Federle
# Charles Haid
# Wilfred Jackson
# Bradley Raymond
# David Lynch
# Enrico Casarosa
# Jenn Nkiru
# David R. Ellis
# Dan Scanlon
# Marc Lawrence
# Gorō Miyazaki
# Angela Robinson
# Burny Mattinson
# Aaron Blaise
# Matt Danner
# Walter Murch
# Joachim Rønning
# William Morgan
# Thomas Kail
# Leslie Woodhead
# Byron Howard
# Charles Jarrott
# Peter Hewitt
# Charles Martin Smith
# Roger Kumble
# Ken Olin
# Andrew V. McLaglen
# Sharon Maguire
# Peggy Holmes
# Ben Sharpsteen
# Harold French
# Chris Sanders
# Richard Fleischer
# Frank Marshall
# Akin Omotoso
# Don Hahn
# John Musker
# Miguel Arteta
# James Cameron
# Jaume Collet-Serra
# Harald Sicheritz
# Dmitriy Dyachenko
# Norman Foster
# Michael Gottlieb
# Art Stevens
# David Hand
# Jack Clayton
# Steve Williams
# Perce Pearce
# Dmitry Dyachenko
# Garry Marshall
# Lee Unkrich
# Jeremy Kagan
# David Swift
# Charles Barton
# Mark Linfield
# Ibra Ake
# Kyle Patrick Alvarez
# Wolfgang Reitherman
# Frederik Du Chau
# Michael Tuchner
# Steven Quale
# Stefan Ruzowitzky

# %%
save_json('directors.json', director_info_list)

# %% [markdown]
# ## cleaning data

# %%
# budget money pattern '$1.5 million' '$2.28 million' '$600,000', None, under $1 million $1,250,000 $3.6–4 million AU$1 million
# $3.5 to 4 million $6-8 million $40–120 million ¥, 2.4 billion, US$24 million $30—$35 million' '' 
# ~$8 million, ₽, 370 million
# ~$70 million $130.4, million $35 thousand

# %%
# box office money with new pattern $76.4–$83.3 million >$1.3 million $3.275 million
# $21,745,500 $1.066 billion $146, million

# %%
def convert_running_time_to_int(x):
    if x == 'N/A':
        return 'N/A'
    else:
        minutes = x.split(' ')[0]
        return int(minutes)

# %%
for movie in movie_info_list:
    runtime = movie.get('Running time', "N/A")
    movie["Running time (int)"] = convert_running_time_to_int(runtime)
    if runtime != "N/A":
        del movie["Running time"]

# %%
import re

amounts = r"thousand|million|billion"
number = r"\d+(,\d{3})*(\.\d+)?"
money_string = fr"\${number}(–|\sto\s|–\$)?({number})?(\s|,\s)({amounts})"

def word_to_value(word):
	value_dict = {"thousand": 1000, "million": 1000_000, "billion": 1000_000_000}
	return value_dict.get(word.lower(), 1)

def parse_word_syntax(string):
	stripped_string = string.replace(",", "")
	value = float(re.search(number, stripped_string).group())
	modifier = word_to_value(re.search(amounts, string, flags=re.I).group())
	return value*modifier

def parse_value_syntax(string):
	stripped_string = string.replace(",", "")
	return float(re.search(number, stripped_string).group())

def money_converter(money):
	string_syntax = re.search(money_string, money, flags=re.I)
	value_syntax = re.search(fr"\${number}", money)

	if string_syntax:
		return parse_word_syntax(string_syntax.group())
	elif value_syntax:
		return parse_value_syntax(value_syntax.group())
	else:
		return ""

# %%
for movie in movie_info_list:
    budget = movie.get('Budget', 'N/A')
    box_office = movie.get('Box office', 'N/A')
    movie["Budget (float)"] = money_converter(budget)
    movie["Box office (float)"] = money_converter(box_office)

    if budget != "N/A":
        del movie["Budget"]
    if box_office != "N/A":
        del movie['Box office']

# %%
movie_info_list
# Out:
# [{'Title': 'Snow White and the Seven Dwarfs',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/49/Snow_White_1937_poster.png/220px-Snow_White_1937_poster.png',
#   'Directed by': ['David Hand',
#    'Perce Pearce',
#    'Larry Morey',
#    'Wilfred Jackson',
#    'Ben Sharpsteen'],
#   'Directors url': ['/wiki/David_Hand_(animator)',
#    '/wiki/Perce_Pearce',
#    '/wiki/Larry_Morey',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Ben_Sharpsteen'],
#   'Story by': 'Ted Sears, Richard Creedon, Otto Englander, Dick Rickard, Earl Hurd, Merrill De Maris, Dorothy Ann Blank, Webb Smith',
#   'Based on': '" Snow White " by the Brothers Grimm',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Adriana Caselotti, Roy Atwell, Pinto Colvig, Otis Harlan, Scotty Mattraw, Billy Gilbert, Eddie Collins',
#   'Music by': 'Frank Churchill, Leigh Harline, Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'December 21, 1937',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 83,
#   'Budget (float)': 1500000.0,
#   'Box office (float)': 418000000.0},
#  {'Title': 'Pinocchio',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/ba/Pinocchio-1940-poster.jpg/220px-Pinocchio-1940-poster.jpg',
#   'Directed by': ['Ben Sharpsteen',
#    'Hamilton Luske',
#    'Norm Ferguson',
#    'Jack Kinney',
#    'Wilfred Jackson',
#    'T. Hee'],
#   'Directors url': ['/wiki/Ben_Sharpsteen',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Norm_Ferguson_(animator)',
#    '/wiki/Jack_Kinney',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/T._Hee'],
#   'Story by': 'Ted Sears, Otto Englander, Webb Smith, William Cottrell, Joseph Sabo, Erdman Penner, Aurelius Battaglia',
#   'Based on': 'The Adventures of Pinocchio by Carlo Collodi',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Cliff Edwards, Dickie Jones, Christian Rub, Walter Catlett, Charles Judels, Evelyn Venable, Frankie Darro',
#   'Music by': 'Leigh Harline, Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'February 7, 1940',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 88,
#   'Budget (float)': 2600000.0,
#   'Box office (float)': 164000000.0},
#  {'Title': 'Fantasia',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/1/12/Fantasia-poster-1940.jpg/220px-Fantasia-poster-1940.jpg',
#   'Directed by': ['James Algar',
#    'Ben Sharpsteen',
#    'David Hand',
#    'Hamilton Luske',
#    'Ford Beebe',
#    'T. Hee',
#    'Norm Ferguson',
#    'Wilfred Jackson'],
#   'Directors url': ['/wiki/James_Algar',
#    '/wiki/Ben_Sharpsteen',
#    '/wiki/David_Hand_(animator)',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Ford_Beebe',
#    '/wiki/T._Hee',
#    '/wiki/Norm_Ferguson_(animator)',
#    '/wiki/Wilfred_Jackson'],
#   'Story by': 'Joe Grant, Dick Huemer',
#   'Produced by': 'Walt Disney, Ben Sharpsteen',
#   'Starring': 'Leopold Stokowski, Deems Taylor',
#   'Cinematography': 'James Wong Howe',
#   'Music by': 'See plot',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'November 13, 1940',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 126,
#   'Budget (float)': 2280000.0,
#   'Box office (float)': 76400000.0},
#  {'Title': 'The Reluctant Dragon',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/fe/Reluctant_Dragon.jpg/220px-Reluctant_Dragon.jpg',
#   'Directed by': ['Alfred Werker',
#    'Hamilton Luske',
#    'Jack Cutting',
#    'Ub Iwerks',
#    'Jack Kinney'],
#   'Directors url': ['/wiki/Alfred_Werker',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Jack_Cutting_(animator)',
#    '/wiki/Ub_Iwerks',
#    '/wiki/Jack_Kinney'],
#   'Written by': 'Live-action:, Ted Sears, Al Perkins, Larry Clemmons, Bill Cottrell, Harry Clork, Robert Benchley, The Reluctant Dragon, segment:, Kenneth Grahame,, Erdman Penner, T. Hee, Baby Weems, segment:, Joe Grant, Dick Huemer, John Miller',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Robert Benchley, Frances Gifford, Buddy Pepper, Nana Bryant',
#   'Cinematography': 'Bert Glennon',
#   'Edited by': 'Paul Weatherwax',
#   'Music by': 'Frank Churchill, Larry Morey',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'June 27, 1941',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 74,
#   'Budget (float)': 600000.0,
#   'Box office (float)': 960000.0},
#  {'Title': 'Dumbo',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/a7/Dumbo-1941-poster.jpg/220px-Dumbo-1941-poster.jpg',
#   'Directed by': ['Ben Sharpsteen',
#    'Norm Ferguson',
#    'Wilfred Jackson',
#    'Jack Kinney'],
#   'Directors url': ['/wiki/Ben_Sharpsteen',
#    '/wiki/Norm_Ferguson_(animator)',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Jack_Kinney'],
#   'Story by': 'Joe Grant, Dick Huemer',
#   'Based on': 'Dumbo, the Flying Elephant by Helen Aberson Harold Pearl',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Edward Brophy, Verna Felton, Cliff Edwards, Herman Bing, Sterling Holloway, Margaret Wright, Hall Johnson Choir',
#   'Narrated by': 'John McLeish',
#   'Music by': 'Frank Churchill, Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'October 23, 1941',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 64,
#   'Budget (float)': 950000.0,
#   'Box office (float)': 1300000.0},
#  {'Title': 'Bambi',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/88/Walt_Disney%27s_Bambi_poster.jpg/220px-Walt_Disney%27s_Bambi_poster.jpg',
#   'Directed by': ['David Hand', 'James Algar'],
#   'Directors url': ['/wiki/David_Hand_(animator)', '/wiki/James_Algar'],
#   'Story by': 'Perce Pearce, Larry Morey, Vernon Stallings, Melvin Shaw, Carl Fallberg, Chuck Couch, Ralph Wright',
#   'Based on': 'Bambi, a Life in the Woods by Felix Salten',
#   'Produced by': 'Walt Disney',
#   'Starring': 'see below',
#   'Music by': 'Frank Churchill, Edward H. Plumb',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'August 9, 1942',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 70,
#   'Budget (float)': 858000.0,
#   'Box office (float)': 267399999.99999997},
#  {'Title': 'Saludos Amigos',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/a/af/Saludosposter.jpg',
#   'Directed by': ['Norm Ferguson',
#    'Wilfred Jackson',
#    'Jack Kinney',
#    'Hamilton Luske'],
#   'Directors url': ['/wiki/Norm_Ferguson_(animator)',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Jack_Kinney',
#    '/wiki/Hamilton_Luske'],
#   'Story by': 'Homer Brightman, William Cottrell, Richard Huemer, Joe Grant, Harold Reeves, Ted Sears, Webb Smith, Roy Williams, Ralph Wright',
#   'Produced by': 'Walt Disney, Norm Ferguson',
#   'Starring': 'Lee Blair, Mary Blair, Pinto Colvig, Walt Disney, Norman Ferguson, Frank Graham, Clarence Nash, José Oliveira, Frank Thomas',
#   'Music by': 'Paul Smith, Edward H. Plumb',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'August 24, 1942',
#   'Country': 'United States',
#   'Languages': 'English, Portuguese, Spanish',
#   'Running time (int)': 42,
#   'Budget (float)': '',
#   'Box office (float)': 1000000.0},
#  {'Title': 'Victory Through Air Power',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/a8/Victory_Through_Air_Power_poster.jpg/220px-Victory_Through_Air_Power_poster.jpg',
#   'Directed by': ['James Algar',
#    'Clyde Geronimi',
#    'Jack Kinney',
#    'H.C. Potter'],
#   'Directors url': ['/wiki/James_Algar',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/Jack_Kinney',
#    '/wiki/H.C._Potter'],
#   'Written by': 'Perce Pearce, T. Hee, Erdman Penner, Bill Cottrell, James Brodero, George Stallings, Jose Rodriguez',
#   'Based on': 'Victory Through Air Power by Maj. Alexander P. Seversky',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Alexander de Seversky',
#   'Narrated by': 'Art Baker',
#   'Cinematography': 'Ray Rennahan',
#   'Edited by': 'Jack Dennis',
#   'Music by': 'Edward H. Plumb, Paul J. Smith, Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'United Artists',
#   'Release date': 'July 17, 1943',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 65,
#   'Budget (float)': 788000.0,
#   'Box office (float)': 799000.0},
#  {'Title': 'The Three Caballeros',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/7b/Three_caballeros_poster.png/220px-Three_caballeros_poster.png',
#   'Directed by': ['Norm Ferguson',
#    'Clyde Geronimi',
#    'Jack Kinney',
#    'Harold Young'],
#   'Directors url': ['/wiki/Norm_Ferguson_(animator)',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/Jack_Kinney',
#    '/wiki/Harold_Young_(director)'],
#   'Story by': 'Homer Brightman, Ernest Terrazas, Ted Sears, Bill Peet, Ralph Wright, Elmer Plummer, Roy Williams, William Cottrell, Del Connell, James Bodrero',
#   'Produced by': 'Walt Disney, Norman Ferguson',
#   'Starring': 'Joaquin Garay, Clarence Nash, José Oliveira, Aurora Miranda, Carmen Molina, Dora Luz',
#   'Music by': 'Edward H. Plumb, Paul J. Smith, Charles Wolcott',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'December 21, 1944',
#   'Country': 'United States',
#   'Languages': 'English, Spanish, Portuguese',
#   'Running time (int)': 71,
#   'Budget (float)': '',
#   'Box office (float)': 3355000.0},
#  {'Title': 'Make Mine Music',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/7d/Make_mine_music_poster.png/220px-Make_mine_music_poster.png',
#   'Directed by': ['Jack Kinney',
#    'Clyde Geronimi',
#    'Hamilton Luske',
#    'Joshua Meador'],
#   'Directors url': ['/wiki/Jack_Kinney',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Joshua_Meador'],
#   'Story by': 'James Bodrero, Homer Brightman, Erwin Graham, Eric Gurney, T. Hee, Sylvia Holland, Dick Huemer, Dick Kelsey, Dick Kinney, Jesse Marsh, Tom Oreb, Cap Palmer, Erdman Penner, Dick Shaw, Harry Reeves, John Walbridge, Roy Williams',
#   'Based on': '" Casey at the Bat " by Ernest Thayer Peter and the Wolf by Sergei Prokofiev',
#   'Produced by': 'Walt Disney, Joe Grant',
#   'Starring': "Nelson Eddy, Dinah Shore, Benny Goodman, The Andrews Sisters, Jerry Colonna, Andy Russell, Sterling Holloway, David Lichine, Tania Riabouchinskaya, The Pied Pipers, The King's Men, The Ken Darby Singers",
#   'Music by': 'Eliot Daniel, Ken Darby, Charles Wolcott, Oliver Wallace, Edward Plumb',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'April 20, 1946',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': 1350000.0,
#   'Box office (float)': 3275000.0},
#  {'Title': 'Song of the South',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/be/Song_of_south_poster.jpg/220px-Song_of_south_poster.jpg',
#   'Directed by': ['Wilfred Jackson'],
#   'Directors url': ['/wiki/Wilfred_Jackson'],
#   'Screenplay by': 'Morton Grant, Maurice Rapf, Dalton S. Reymond, Bill Peet, George Stallings, Ralph Wright',
#   'Based on': '" Uncle Remus " by Joel Chandler Harris',
#   'Produced by': 'Walt Disney, Perce Pearce',
#   'Starring': 'Ruth Warrick, Lucile Watson, Hattie McDaniel, James Baskett, Bobby Driscoll, Luana Patten',
#   'Cinematography': 'Gregg Toland',
#   'Edited by': 'William M. Morgan',
#   'Music by': 'Daniele Amfitheatrof, Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'November 12, 1946',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 94,
#   'Budget (float)': 2125000.0,
#   'Box office (float)': 65000000.0},
#  {'Title': 'Fun and Fancy Free',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/b/b4/Funfanposter.jpg',
#   'Directed by': ['Jack Kinney', 'Hamilton Luske', 'William Morgan'],
#   'Directors url': ['/wiki/Jack_Kinney',
#    '/wiki/Hamilton_Luske',
#    '/wiki/William_Morgan_(director)'],
#   'Story by': 'Homer Brightman, Eldon Dedini, Lance Nolley, Tom Oreb, Harry Reeves, Ted Sears',
#   'Based on': '" Little Bear Bongo " by Sinclair Lewis " Jack and the Beanstalk "',
#   'Produced by': 'Walt Disney, Ben Sharpsteen',
#   'Starring': 'Cliff Edwards, Edgar Bergen, Luana Patten, Walt Disney, Clarence Nash, Pinto Colvig, Billy Gilbert, Anita Gordon',
#   'Edited by': 'Jack Bachom',
#   'Music by': 'Oliver Wallace, Paul Smith, Eliot Daniel, Charles Wolcott',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'September 27, 1947',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 73,
#   'Budget (float)': '',
#   'Box office (float)': 3165000.0},
#  {'Title': 'Melody Time',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/26/Melody_Time_poster.jpg/220px-Melody_Time_poster.jpg',
#   'Directed by': ['Clyde Geronimi',
#    'Wilfred Jackson',
#    'Hamilton Luske',
#    'Jack Kinney'],
#   'Directors url': ['/wiki/Clyde_Geronimi',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Jack_Kinney'],
#   'Story by': 'Winston Hibler, Erdman Penner, Harry Reeves, Homer Brightman, Ken Anderson, Ted Sears, Joe Rinaldi, Bill Cottrell, Art Scott, Jesse Marsh, Bob Moore, John Walbridge',
#   'Produced by': 'Walt Disney, Ben Sharpsteen',
#   'Starring': 'Roy Rogers, Trigger, Dennis Day, The Andrews Sisters, Fred Waring and the Pennsylvanians, Freddy Martin, Ethel Smith, Frances Langford, Buddy Clark',
#   'Cinematography': 'Winton Hoch',
#   'Edited by': 'Donald Halliday, Thomas Scott',
#   'Music by': 'Eliot Daniel, Paul J. Smith, Ken Darby',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'May 27, 1948',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': 1500000.0,
#   'Box office (float)': 2560000.0},
#  {'Title': 'So Dear to My Heart',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/ab/So_Dear_to_My_Heart_poster.jpg/220px-So_Dear_to_My_Heart_poster.jpg',
#   'Directed by': ['Harold D. Schuster', 'Hamilton Luske'],
#   'Directors url': ['/wiki/Harold_D._Schuster', '/wiki/Hamilton_Luske'],
#   'Written by': 'Ken Anderson, John Tucker Battle, Marc Davis, Bill Peet, Maurice Rapf, Ted Sears',
#   'Based on': 'Midnight and Jeremiah by Sterling North',
#   'Produced by': 'Walt Disney, Perce Pearce',
#   'Starring': 'Burl Ives, Beulah Bondi, Harry Carey, Luana Patten, Bobby Driscoll',
#   'Cinematography': 'Winton C. Hoch',
#   'Edited by': 'Lloyd L. Richardson, Thomas Scott',
#   'Music by': 'Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'November 29, 1948 (Chicago)',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 82,
#   'Budget (float)': 1500000.0,
#   'Box office (float)': 4500000.0},
#  {'Title': 'The Adventures of Ichabod and Mr. Toad',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/77/Ichabodposter.jpg/220px-Ichabodposter.jpg',
#   'Directed by': ['Ben Sharpsteen',
#    'Jack Kinney',
#    'Clyde Geronimi',
#    'James Algar'],
#   'Directors url': ['/wiki/Ben_Sharpsteen',
#    '/wiki/Jack_Kinney',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/James_Algar'],
#   'Story by': 'Erdman Penner, Winston Hibler, Joe Rinaldi, Ted Sears, Homer Brightman, Harry Reeves',
#   'Based on': 'The Wind in the Willows by Kenneth Grahame " The Legend of Sleepy Hollow " by Washington Irving',
#   'Produced by': 'Walt Disney',
#   'Starring': "Bing Crosby, Basil Rathbone, Eric Blore, J. Pat O'Malley, John Ployardt, Colin Campbell, Campbell Grant, Claude Allister, The Rhythmaires",
#   'Edited by': 'John O. Young',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'October 5, 1949',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 68,
#   'Budget (float)': '',
#   'Box office (float)': 1625000.0},
#  {'Title': 'Cinderella',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/1/13/Cinderella_%28Official_1950_Film_Poster%29.png',
#   'Directed by': ['Wilfred Jackson', 'Hamilton Luske', 'Clyde Geronimi'],
#   'Directors url': ['/wiki/Wilfred_Jackson',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Clyde_Geronimi'],
#   'Story by': 'William Peet, Ted Sears, Homer Brightman, Kenneth Anderson, Erdman Penner, Winston Hibler, Harry Reeves, Joe Rinaldi',
#   'Based on': '" Cinderella " by Charles Perrault',
#   'Produced by': 'Walt Disney, Ben Sharpsteen',
#   'Starring': 'Ilene Woods, Eleanor Audley, Verna Felton, Rhoda Williams, James MacDonald, Luis van Rooten',
#   'Edited by': 'Donald Halliday',
#   'Music by': 'Oliver Wallace, Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'February 15, 1950',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 74,
#   'Budget (float)': 2200000.0,
#   'Box office (float)': 182000000.0},
#  {'Title': 'Treasure Island',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/89/Treasure_Island_%281950_film%29_poster.jpg/220px-Treasure_Island_%281950_film%29_poster.jpg',
#   'Directed by': ['Byron Haskin'],
#   'Directors url': ['/wiki/Byron_Haskin'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Based on': 'Treasure Island by Robert Louis Stevenson',
#   'Produced by': 'Walt Disney, Perce Pearce',
#   'Starring': 'Bobby Driscoll, Robert Newton, Basil Sydney, Finlay Currie',
#   'Cinematography': 'Freddie Young',
#   'Edited by': 'Alan Jaggs',
#   'Music by': 'Clifton Parker',
#   'Production company': 'RKO-Walt Disney British Productions Limited',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'June 22, 1950',
#   'Countries': 'United States, United Kingdom',
#   'Language': 'English',
#   'Running time (int)': 96,
#   'Budget (float)': 1800000.0,
#   'Box office (float)': 4099999.9999999995},
#  {'Title': 'Alice in Wonderland',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c1/Alice_in_Wonderland_%281951_film%29_poster.jpg/220px-Alice_in_Wonderland_%281951_film%29_poster.jpg',
#   'Directed by': ['Ben Sharpsteen',
#    'Clyde Geronimi',
#    'Wilfred Jackson',
#    'Hamilton Luske'],
#   'Directors url': ['/wiki/Ben_Sharpsteen',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Hamilton_Luske'],
#   'Story by': 'Winston Hibler, Ted Sears, Bill Peet, Erdman Penner, Joe Rinaldi, Milt Banta, Bill Cottrell, Dick Kelsey, Joe Grant, Dick Huemer, Del Connell, Tom Oreb, John Walbridge',
#   'Based on': "Alice's Adventures in Wonderland and Through the Looking-Glass by Lewis Carroll",
#   'Produced by': 'Walt Disney',
#   'Starring': "Kathryn Beaumont, Ed Wynn, Richard Haydn, Sterling Holloway, Jerry Colonna, Verna Felton, J. Pat O'Malley, Bill Thompson, Heather Angel",
#   'Edited by': 'Lloyd Richardson',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': 'July 26, 1951',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': 3000000.0,
#   'Box office (float)': 2400000.0},
#  {'Title': 'The Story of Robin Hood and his Merrie Men',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/a0/Story_of_robin_hoodsxf.jpg/220px-Story_of_robin_hoodsxf.jpg',
#   'Directed by': ['Ken Annakin'],
#   'Directors url': ['/wiki/Ken_Annakin'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Produced by': 'Perce Pearce, Walt Disney',
#   'Starring': 'Richard Todd, Joan Rice, Peter Finch',
#   'Cinematography': 'Guy Green',
#   'Edited by': 'Gordon Pilkington',
#   'Music by': 'Clifton Parker',
#   'Production company': 'RKO-Walt Disney British Productions Limited',
#   'Distributed by': 'RKO Radio Pictures Ltd.',
#   'Release dates': '13 March 1952',
#   'Countries': 'United States, United Kingdom',
#   'Language': 'English',
#   'Running time (int)': 84,
#   'Budget (float)': '',
#   'Box office (float)': 2100000.0},
#  {'Title': 'Peter Pan',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/46/PeterpanRKO.jpg/220px-PeterpanRKO.jpg',
#   'Directed by': ['Hamilton Luske', 'Clyde Geronimi', 'Wilfred Jackson'],
#   'Directors url': ['/wiki/Hamilton_Luske',
#    '/wiki/Clyde_Geronimi',
#    '/wiki/Wilfred_Jackson'],
#   'Story by': 'Ted Sears, Erdman Penner, Bill Peet, Winston Hibler, Joe Rinaldi, Milt Banta, Ralph Wright, Bill Cottrell',
#   'Based on': 'Peter and Wendy by J. M. Barrie',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Bobby Driscoll, Kathryn Beaumont, Hans Conried, Bill Thompson, Heather Angel, Paul Collins, Tommy Luske, Candy Candido',
#   'Narrated by': 'Tom Conway',
#   'Edited by': 'Donald Halliday',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release date': 'February 5, 1953',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 77,
#   'Budget (float)': 4000000.0,
#   'Box office (float)': 87400000.0},
#  {'Title': 'The Sword and the Rose',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/8f/The_Sword_and_the_Rose_poster.jpg/220px-The_Sword_and_the_Rose_poster.jpg',
#   'Directed by': ['Ken Annakin'],
#   'Directors url': ['/wiki/Ken_Annakin'],
#   'Screenplay by': 'Lawrence Edward Watkin',
#   'Based on': 'When Knighthood Was in Flower by Charles Major James B. Fagan',
#   'Produced by': 'Perce Pearce, Walt Disney',
#   'Starring': 'Glynis Johns, James Robertson Justice, Richard Todd, Michael Gough, Jane Barrett, Peter Copley, Ernest Jay, Jean Mercure, D. A. Clarke-Smith, Gérard Oury, Fernand Fabre, Gaston Richer, Rosalie Crutchley, Bryan Coleman',
#   'Cinematography': 'Geoffrey Unsworth',
#   'Edited by': 'Gerald Thomas',
#   'Music by': 'Clifton Parker',
#   'Production company': 'RKO-Walt Disney British Productions Limited',
#   'Distributed by': 'RKO Radio Pictures Ltd.',
#   'Release date': 'July 23, 1953',
#   'Countries': 'United Kingdom, United States',
#   'Language': 'English',
#   'Running time (int)': 92,
#   'Budget (float)': 2000000.0,
#   'Box office (float)': 1000000.0},
#  {'Title': 'The Living Desert',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/0/05/Living_Prairie.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar, Winston Hibler',
#   'Produced by': 'Ben Sharpsteen, Walt Disney',
#   'Narrated by': 'Winston Hibler',
#   'Cinematography': 'Robert H. Crandall, N. Paul Kenworthy',
#   'Edited by': 'Norman R. Palmer',
#   'Music by': 'Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'November 9, 1953',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 69,
#   'Budget (float)': 300000.0,
#   'Box office (float)': 2600000.0},
#  {'Title': 'Rob Roy: The Highland Rogue',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b7/Poster_of_the_movie_Rob_Roy%2C_the_Highland_Rogue.jpg/220px-Poster_of_the_movie_Rob_Roy%2C_the_Highland_Rogue.jpg',
#   'Directed by': ['Harold French'],
#   'Directors url': ['/wiki/Harold_French'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Produced by': 'Perce Pearce, Walt Disney',
#   'Starring': 'Richard Todd, Glynis Johns, James Robertson Justice, Michael Gough, Finlay Currie, Geoffrey Keen',
#   'Cinematography': 'Guy Green',
#   'Edited by': 'Geoffrey Foot',
#   'Music by': 'Cedric Thorpe Davie',
#   'Production company': 'RKO-Walt Disney British Productions',
#   'Distributed by': 'RKO Radio Pictures',
#   'Release dates': '26 October 1953',
#   'Countries': 'United Kingdom, United States',
#   'Language': 'English',
#   'Running time (int)': 81,
#   'Budget (float)': 1800000.0,
#   'Box office (float)': 1050000.0},
#  {'Title': 'The Vanishing Prairie',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/6/60/The_Vanishing_Prairie_-_official_poster.jpg/220px-The_Vanishing_Prairie_-_official_poster.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar, Winston Hibler',
#   'Produced by': 'Ben Sharpsteen, Walt Disney',
#   'Narrated by': 'Winston Hibler',
#   'Cinematography': 'N. Paul Kenworthy',
#   'Edited by': 'Lloyd L. Richardson',
#   'Music by': 'Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'August 17, 1954',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 60,
#   'Budget (float)': '',
#   'Box office (float)': 1750000.0},
#  {'Title': '20,000 Leagues Under the Sea',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b8/20000leaguesposter.jpg/220px-20000leaguesposter.jpg',
#   'Directed by': ['Richard Fleischer'],
#   'Directors url': ['/wiki/Richard_Fleischer'],
#   'Screenplay by': 'Earl Felton',
#   'Based on': 'Twenty Thousand Leagues Under the Seas by Jules Verne',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Kirk Douglas, James Mason, Paul Lukas, Peter Lorre',
#   'Cinematography': 'Franz Planer',
#   'Edited by': 'Elmo Williams',
#   'Music by': 'Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 23, 1954',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 127,
#   'Budget (float)': 5000000.0,
#   'Box office (float)': 28200000.0},
#  {'Title': None,
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/4d/Davy_Crockett%2C_King_of_the_Wild_Frontier_FilmPoster.jpeg/220px-Davy_Crockett%2C_King_of_the_Wild_Frontier_FilmPoster.jpeg',
#   'Directed by': ['Norman Foster'],
#   'Directors url': ['/wiki/Norman_Foster_(director)'],
#   'Written by': 'Tom Blackburn',
#   'Produced by': 'Bill Walsh',
#   'Starring': 'Fess Parker, Buddy Ebsen',
#   'Cinematography': 'Charles P. Boyle',
#   'Edited by': 'Chester W. Schaeffer',
#   'Music by': 'Thomas W. Blackburn, George Bruns, Edward H. Plumb,',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Film Distribution Co., Inc.',
#   'Release date': 'May 25, 1955',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 93,
#   'Budget (float)': '',
#   'Box office (float)': 2150000.0},
#  {'Title': 'Lady and the Tramp',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/3/39/Lady-and-tramp-1955-poster.jpg/220px-Lady-and-tramp-1955-poster.jpg',
#   'Directed by': ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilton Luske'],
#   'Directors url': ['/wiki/Clyde_Geronimi',
#    '/wiki/Wilfred_Jackson',
#    '/wiki/Hamilton_Luske'],
#   'Story by': 'Erdman Penner, Joe Rinaldi, Ralph Wright, Don DaGradi, Joe Grant',
#   'Based on': '"Happy Dan, the Cynical Dog" by Ward Greene',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Barbara Luddy, Larry Roberts, Bill Thompson, Dallas McKennon, Bill Baucom, Verna Felton, Peggy Lee',
#   'Edited by': 'Don Halliday',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Film Distribution',
#   'Release date': 'June 22, 1955',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 76,
#   'Budget (float)': 4000000.0,
#   'Box office (float)': 187000000.0},
#  {'Title': 'The African Lion',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/dc/Poster_of_the_movie_The_African_Lion.jpg/220px-Poster_of_the_movie_The_African_Lion.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar, Winston Hibler',
#   'Produced by': 'Walt Disney, Ben Sharpsteen',
#   'Narrated by': 'Winston Hibler',
#   'Cinematography': 'Alfred Milotte, Elma Milotte',
#   'Edited by': 'Norman R. Palmer',
#   'Music by': 'Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'September 14, 1955',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': '',
#   'Box office (float)': 2100000.0},
#  {'Title': 'The Littlest Outlaw',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/04/The_Littlest_Outlaw.jpg/220px-The_Littlest_Outlaw.jpg',
#   'Directed by': ['Roberto Gavaldón'],
#   'Directors url': ['/wiki/Roberto_Gavald%C3%B3n'],
#   'Starring': 'Pedro Armendáriz, Joseph Calleia, Andrés Velázquez',
#   'Cinematography': 'Alex Phillips',
#   'Edited by': 'Carlos Savage',
#   'Music by': 'William Lava',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 22, 1955',
#   'Countries': 'United States, Mexico',
#   'Languages': 'English, Spanish',
#   'Running time (int)': 73,
#   'Budget (float)': '',
#   'Box office (float)': 1600000.0},
#  {'Title': 'The Great Locomotive Chase',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b9/The_poster_of_the_movie_The_Great_Locomotive_Chase.jpg/220px-The_poster_of_the_movie_The_Great_Locomotive_Chase.jpg',
#   'Directed by': ['Francis D. Lyon'],
#   'Directors url': ['/wiki/Francis_D._Lyon'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Produced by': 'Lawrence Edward Watkin, Walt Disney',
#   'Starring': 'Fess Parker, Jeffrey Hunter, John Lupton, Jeff York, Slim Pickens',
#   'Cinematography': 'Charles Boyle',
#   'Edited by': 'Ellsworth Hoagland',
#   'Music by': 'Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'June 8, 1956',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 85,
#   'Budget (float)': '',
#   'Box office (float)': 1700000.0},
#  {'Title': None,
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c9/Davy_Crockett_and_the_River_Pirates.jpg/220px-Davy_Crockett_and_the_River_Pirates.jpg',
#   'Directed by': ['Norman Foster'],
#   'Directors url': ['/wiki/Norman_Foster_(director)'],
#   'Written by': 'Tom Blackburn, Norman Foster',
#   'Produced by': 'Bill Walsh',
#   'Starring': 'Fess Parker, Buddy Ebsen, Jeff York',
#   'Cinematography': 'Bert Glennon',
#   'Edited by': 'Stanley Johnson',
#   'Music by': 'Thomas W. Blackburn, George Bruns, Edward H. Plumb,',
#   'Color process': 'Technicolor',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Film Distribution Co., Inc.',
#   'Release date': 'July 18, 1956',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 81,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Secrets of Life',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/5/5c/Secrets_of_Life_poster.jpg/220px-Secrets_of_Life_poster.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar',
#   'Produced by': 'Ben Sharpsteen, Walt Disney',
#   'Narrated by': 'Winston Hibler',
#   'Cinematography': 'William A. Anderson, Arthur Carter, Jack Couffer, Robert H. Crandall, Murl Deusing, Fran William Hall, Claude Jendrusch, Stuart V. Jewell, George MacGinitie, Nettie MacGinitie, Tilden W. Roberts, Donald L. Sykes, Roman Vishniac',
#   'Edited by': 'Anthony Gerard',
#   'Music by': 'Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'September 4, 1956',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 70,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Westward Ho the Wagons!',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/44/Westward_Ho_the_Wagons%21_poster.jpg/220px-Westward_Ho_the_Wagons%21_poster.jpg',
#   'Directed by': ['William Beaudine'],
#   'Directors url': ['/wiki/William_Beaudine'],
#   'Screenplay by': 'Tom Blackburn',
#   'Based on': 'Children of the Covered Wagon by Mary Jane Carr',
#   'Produced by': 'Bill Walsh',
#   'Starring': 'Fess Parker, Kathleen Crowley, Jeff York, Sebastian Cabot, George Reeves, David Stollery',
#   'Cinematography': 'Charles P. Boyle, ,, A.S.C.',
#   'Edited by': 'Cotton Warburton, ,, A.C.E.',
#   'Music by': 'George Bruns',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 20, 1956',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 90,
#   'Budget (float)': '',
#   'Box office (float)': 2750000.0},
#  {'Title': 'Johnny Tremain',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/79/Johnny_Tremain_poster.jpg/220px-Johnny_Tremain_poster.jpg',
#   'Directed by': ['Robert Stevenson'],
#   'Directors url': ['/wiki/Robert_Stevenson_(director)'],
#   'Written by': 'Esther Forbes, Tom Blackburn',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Hal Stalmaster, Luana Patten, Jeff York, Sebastian Cabot',
#   'Cinematography': 'Charles P. Boyle',
#   'Edited by': 'Stanley E. Johnson',
#   'Music by': 'George Bruns, Tom Blackburn, Song "Liberty Tree" by George Bruns and Tom Blackburn',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'June 19, 1957',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 80,
#   'Budget (float)': 700000.0,
#   'Box office (float)': ''},
#  {'Title': 'Perri',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c1/Perri_FilmPoster.jpeg/220px-Perri_FilmPoster.jpeg',
#   'Directed by': ['N. Paul Kenworthy', 'Ralph Wright'],
#   'Directors url': ['/wiki/N._Paul_Kenworthy', '/wiki/Ralph_Wright'],
#   'Written by': 'Ralph Wright, Winston Hibler, Felix Salten',
#   'Produced by': 'Winston Hibler',
#   'Narrated by': 'Winston Hibler',
#   'Edited by': 'Jack Atwood',
#   'Music by': ':, Paul J. Smith, :, George Bruns, Winston Hibler, Ralph Wright, Paul J. Smith, Hazel "Gil" George, :, Carl Brandt, :, Carl Brandt, Franklyn Marks',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'August 28, 1957',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': '',
#   'Box office (float)': 1750000.0},
#  {'Title': 'Old Yeller',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Old_Yeller_%281957_film_poster%29.jpg/220px-Old_Yeller_%281957_film_poster%29.jpg',
#   'Directed by': ['Robert Stevenson'],
#   'Directors url': ['/wiki/Robert_Stevenson_(director)'],
#   'Screenplay by': 'Fred Gipson, William Tunberg',
#   'Based on': 'Old Yeller by Fred Gipson',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Dorothy McGuire, Fess Parker, Jeff York, Tommy Kirk, Kevin Corcoran, Beverly Washburn, Chuck Connors',
#   'Cinematography': 'Charles P. Boyle',
#   'Edited by': 'Stanley E. Johnson',
#   'Music by': 'Oliver Wallace, Will Schaefer',
#   'Color process': 'Technicolor',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 25, 1957',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 84,
#   'Budget (float)': '',
#   'Box office (float)': 6250000.0},
#  {'Title': 'The Light in the Forest',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/06/The_Light_in_the_Forest_1958.jpg/220px-The_Light_in_the_Forest_1958.jpg',
#   'Directed by': ['Herschel Daugherty'],
#   'Directors url': ['/wiki/Herschel_Daugherty'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Based on': 'novel by Conrad Richter',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Fess Parker, Wendell Corey, Joanne Dru, James MacArthur, Jessica Tandy',
#   'Cinematography': 'Ellsworth Fredericks',
#   'Music by': 'Paul J. Smith, Franklyn Marks',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'July 8, 1958',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 83,
#   'Budget (float)': '',
#   'Box office (float)': 2000000.0},
#  {'Title': 'White Wilderness',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/8c/White_Wilderness_-_theatrical_poster.jpg/220px-White_Wilderness_-_theatrical_poster.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar',
#   'Produced by': 'Ben Sharpsteen, ,, Walt Disney',
#   'Narrated by': 'Winston Hibler',
#   'Edited by': 'Norman R. Palmer',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'August 12, 1958',
#   'Countries': 'United States, Canada',
#   'Language': 'English',
#   'Running time (int)': 72,
#   'Budget (float)': '',
#   'Box office (float)': 1800000.0},
#  {'Title': 'Tonka',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/5/57/Tonka_poster.jpg/220px-Tonka_poster.jpg',
#   'Directed by': ['Lewis R. Foster'],
#   'Directors url': ['/wiki/Lewis_R._Foster'],
#   'Written by': 'David Appel, Lewis R. Foster, Lillie Hayward',
#   'Based on': "Comanche: Story of America's Most Heroic Horse by David Appel",
#   'Produced by': 'James C. Pratt',
#   'Starring': 'Sal Mineo, Philip Carey, Jerome Courtland, Rafael Campos',
#   'Cinematography': 'Loyal Griggs',
#   'Edited by': 'Ellsworth Hoagland',
#   'Music by': 'Oliver Wallace',
#   'Color process': 'Technicolor',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 25, 1958',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 97,
#   'Budget (float)': '',
#   'Box office (float)': 2500000.0},
#  {'Title': 'Sleeping Beauty',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/43/Sleeping_beauty_disney.jpg/220px-Sleeping_beauty_disney.jpg',
#   'Directed by': ['Clyde Geronimi',
#    'Wolfgang Reitherman',
#    'Eric Larson',
#    'Les Clark'],
#   'Directors url': ['/wiki/Clyde_Geronimi',
#    '/wiki/Wolfgang_Reitherman',
#    '/wiki/Eric_Larson',
#    '/wiki/Les_Clark'],
#   'Story by': 'Erdman Penner, Joe Rinaldi, Winston Hibler, Bill Peet, Ted Sears, Ralph Wright, Milt Banta',
#   'Based on': '" Sleeping Beauty " by Charles Perrault',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Mary Costa, Bill Shirley, Eleanor Audley, Verna Felton, Barbara Luddy, Barbara Jo Allen, Taylor Holmes, Bill Thompson',
#   'Edited by': 'Roy M. Brewer Jr., Donald Halliday',
#   'Music by': 'George Bruns',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'January 29, 1959',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': 6000000.0,
#   'Box office (float)': 51600000.0},
#  {'Title': 'The Shaggy Dog',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/71/The_Shaggy_Dog_-_1963_-_Poster.png/220px-The_Shaggy_Dog_-_1963_-_Poster.png',
#   'Directed by': ['Charles Barton'],
#   'Directors url': ['/wiki/Charles_Barton_(director)'],
#   'Screenplay by': 'Lillie Hayward, Bill Walsh',
#   'Based on': 'The Hound of Florence by Felix Salten',
#   'Produced by': 'Walt Disney, Bill Walsh',
#   'Starring': 'Fred MacMurray, Jean Hagen, Tommy Kirk, Annette Funicello, Cecil Kellaway, Alexander Scourby, James Westerfield, Jacques Aubuchon',
#   'Narrated by': 'Paul Frees',
#   'Cinematography': 'Edward Colman',
#   'Edited by': 'James Ballas',
#   'Music by': 'Paul J. Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'March 19, 1959',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 104,
#   'Budget (float)': 1000000.0,
#   'Box office (float)': 12300000.0},
#  {'Title': "Darby O'Gill and the Little People",
#   'Poster': 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/16/Darby_o_gill_and_the_little_people.jpg/220px-Darby_o_gill_and_the_little_people.jpg',
#   'Directed by': ['Robert Stevenson'],
#   'Directors url': ['/wiki/Robert_Stevenson_(director)'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Based on': "Darby O'Gill by H. T. Kavanagh",
#   'Produced by': 'Bill Anderson, Walt Disney',
#   'Starring': "Albert Sharpe, Janet Munro, Sean Connery, Jimmy O'Dea, Kieron Moore, Estelle Winwood, Walter Fitzgerald",
#   'Cinematography': 'Winton Hoch',
#   'Edited by': 'Stanley Johnson',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release dates': 'June 24, 1959',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 93,
#   'Budget (float)': '',
#   'Box office (float)': 2600000.0},
#  {'Title': 'Third Man on the Mountain',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/3/30/Third_Man_on_the_Mountain_poster.jpg/220px-Third_Man_on_the_Mountain_poster.jpg',
#   'Directed by': ['Ken Annakin'],
#   'Directors url': ['/wiki/Ken_Annakin'],
#   'Written by': 'Eleanore Griffin',
#   'Based on': 'Banner in the Sky 1954 novel by James Ramsey Ullman',
#   'Produced by': 'Bill Anderson, Walt Disney',
#   'Starring': 'Michael Rennie, James MacArthur, Janet Munro',
#   'Cinematography': 'Harry Waxman',
#   'Edited by': 'Peter Boita',
#   'Music by': 'William Alwyn',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'November 10, 1959',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 105,
#   'Budget (float)': 2000000.0,
#   'Box office (float)': 1700000.0},
#  {'Title': None,
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/71/Toby_Tyler_poster.jpg/220px-Toby_Tyler_poster.jpg',
#   'Directed by': ['Charles Barton'],
#   'Directors url': ['/wiki/Charles_Barton_(director)'],
#   'Written by': 'Lillie Hayward, Bill Walsh',
#   'Based on': 'Toby Tyler; or, Ten Weeks with a Circus by James Otis Kaler',
#   'Produced by': 'Bill Walsh',
#   'Starring': 'Kevin Corcoran, Henry Calvin, Gene Sheldon, Richard Eastham',
#   'Music by': 'Buddy Baker',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'January 21, 1960',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 95,
#   'Budget (float)': '',
#   'Box office (float)': 3100000.0},
#  {'Title': 'Kidnapped',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/Kidnapped1960poster.jpg/220px-Kidnapped1960poster.jpg',
#   'Directed by': ['Robert Stevenson'],
#   'Directors url': ['/wiki/Robert_Stevenson_(director)'],
#   'Written by': 'Robert Stevenson',
#   'Based on': 'Kidnapped by Robert Louis Stevenson',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Peter Finch, James MacArthur, Bernard Lee',
#   'Cinematography': 'Paul Beeson',
#   'Edited by': 'Gordon Stone',
#   'Music by': 'Cedric Thorpe Davie',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'February 24, 1960',
#   'Country': 'United States',
#   'Languages': 'English, Scots',
#   'Running time (int)': 97,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Pollyanna',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d6/Pollyanna_%281960_film%29_poster.jpg/220px-Pollyanna_%281960_film%29_poster.jpg',
#   'Directed by': ['David Swift'],
#   'Directors url': ['/wiki/David_Swift_(director)'],
#   'Screenplay by': 'David Swift',
#   'Based on': 'Pollyanna by Eleanor Porter',
#   'Produced by': 'Walt Disney',
#   'Starring': 'Jane Wyman, Richard Egan, Karl Malden, Nancy Olson, Adolphe Menjou, Donald Crisp, Agnes Moorehead, Kevin Corcoran, Hayley Mills',
#   'Cinematography': 'Russell Harlan',
#   'Edited by': 'Frank Gross',
#   'Music by': 'Paul Smith',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'May 19, 1960',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 134,
#   'Budget (float)': 2500000.0,
#   'Box office (float)': 3750000.0},
#  {'Title': 'Jungle Cat',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b0/Jungle_Cat_poster.jpg/220px-Jungle_Cat_poster.jpg',
#   'Directed by': ['James Algar'],
#   'Directors url': ['/wiki/James_Algar'],
#   'Written by': 'James Algar',
#   'Produced by': 'Ben Sharpsteen, Walt Disney',
#   'Narrated by': 'Winston Hibler',
#   'Cinematography': 'Lloyd Beebe, James R. Simon, Hugh A. Wilmar',
#   'Edited by': 'Norman R. Palmer',
#   'Music by': 'Oliver Wallace',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release dates': 'June 1960',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 69,
#   'Budget (float)': '',
#   'Box office (float)': 2300000.0},
#  {'Title': 'Ten Who Dared',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d1/Poster_of_the_movie_Ten_Who_Dared.jpg/220px-Poster_of_the_movie_Ten_Who_Dared.jpg',
#   'Directed by': ['William Beaudine'],
#   'Directors url': ['/wiki/William_Beaudine'],
#   'Written by': 'Lawrence Edward Watkin',
#   'Based on': 'journal by John Wesley Powell',
#   'Produced by': 'Walt Disney, James Algar',
#   'Starring': 'Brian Keith, John Beal, James Drury',
#   'Cinematography': 'Gordon Avil',
#   'Edited by': 'Norman Palmer, Cotton Warburton',
#   'Music by': 'Oliver Wallace',
#   'Color process': 'Technicolor',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'November 1, 1960',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 92,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Swiss Family Robinson',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/aa/Swiss_family_robinson322.jpg/220px-Swiss_family_robinson322.jpg',
#   'Directed by': ['Ken Annakin'],
#   'Directors url': ['/wiki/Ken_Annakin'],
#   'Written by': 'Lowell S. Hawley',
#   'Based on': 'The Swiss Family Robinson by Johann David Wyss',
#   'Produced by': 'Bill Anderson, Basil Keys, Walt Disney',
#   'Starring': 'John Mills, Dorothy McGuire, James MacArthur, Janet Munro, Sessue Hayakawa, Tommy Kirk, Kevin Corcoran, Cecil Parker, Andy Ho, Milton Reid, Larry Taylor',
#   'Cinematography': 'Harry Waxman',
#   'Edited by': 'Peter Boita',
#   'Music by': 'William Alwyn',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'December 21, 1960',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 126,
#   'Budget (float)': 4000000.0,
#   'Box office (float)': 40000000.0},
#  {'Title': 'One Hundred and One Dalmatians',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/cd/One_Hundred_and_One_Dalmatians_movie_poster.jpg/220px-One_Hundred_and_One_Dalmatians_movie_poster.jpg',
#   'Directed by': ['Wolfgang Reitherman', 'Hamilton Luske', 'Clyde Geronimi'],
#   'Directors url': ['/wiki/Wolfgang_Reitherman',
#    '/wiki/Hamilton_Luske',
#    '/wiki/Clyde_Geronimi'],
#   'Screenplay by': 'Bill Peet,',
#   'Story by': 'Bill Peet',
#   'Based on': 'The Hundred and One Dalmatians by Dodie Smith',
#   'Produced by': 'Walt Disney',
#   'Starring': "Rod Taylor, J. Pat O'Malley, Betty Lou Gerson, Martha Wentworth, Ben Wright, Cate Bauer, Dave Frankham, Fred Worlock",
#   'Edited by': 'Roy M. Brewer, Jr., Donald Halliday',
#   'Music by': 'George Bruns',
#   'Production company': 'Walt Disney Productions',
#   'Distributed by': 'Buena Vista Distribution',
#   'Release date': 'January 25, 1961',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 79,
#   'Budget (float)': 3600000.0,
#   'Box office (float)': 303000000.0},
#  {'Title': 'The Absent-Minded Professor',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/fd/The_Absent-Minded_Professor_-_1963_-_Poster.png/220px-The_Absent-Minded_Professor_-_1963_-_Poster.png',
#   'Directed by': ['Robert Stevenson'],
#   'Directors url': ['/wiki/Robert_Stevenson_(filmmaker)'],
#   'Screenplay by': 'Bill Walsh',
#   'Based on': '"A Situation of Gravity" by Samuel W. Taylor',
#   'Produced by': 'Walt Disney',
# ...
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Pinocchio',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/5/5b/Pinocchio_2022_film_poster.png/220px-Pinocchio_2022_film_poster.png',
#   'Directed by': ['Robert Zemeckis'],
#   'Directors url': ['/wiki/Robert_Zemeckis'],
#   'Screenplay by': 'Robert Zemeckis, Chris Weitz',
#   'Based on': "Disney 's Pinocchio The Adventures of Pinocchio by Carlo Collodi",
#   'Produced by': 'Andrew Milano, Chris Weitz, Robert Zemeckis, Derek Hogue',
#   'Starring': 'Tom Hanks, Benjamin Evan Ainsworth, Joseph Gordon-Levitt, Keegan-Michael Key, Lorraine Bracco, Cynthia Erivo, Luke Evans',
#   'Cinematography': 'Don Burgess',
#   'Edited by': 'Jesse Goldsmith, Mick Audsley',
#   'Music by': 'Alan Silvestri',
#   'Production companies': 'Walt Disney Pictures, Depth of Field, ImageMovers',
#   'Distributed by': 'Disney+',
#   'Release date': 'September 8, 2022',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 105,
#   'Budget (float)': 150000000.0,
#   'Box office (float)': ''},
#  {'Title': 'Hocus Pocus 2',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f4/Hocus_Pocus_2_Logo.jpg/220px-Hocus_Pocus_2_Logo.jpg',
#   'Directed by': ['Anne Fletcher'],
#   'Directors url': ['/wiki/Anne_Fletcher'],
#   'Screenplay by': "Jen D'Angelo",
#   'Based on': 'Characters by Mick Garris David Kirschner',
#   'Produced by': 'Lynn Harris',
#   'Starring': 'Bette Midler, Sarah Jessica Parker, Kathy Najimy, Sam Richardson, Doug Jones, Whitney Peak, Belissa Escobedo, Tony Hale, Hannah Waddingham',
#   'Cinematography': 'Elliot Davis',
#   'Edited by': 'Julia Wong',
#   'Music by': 'John Debney',
#   'Production companies': 'Walt Disney Pictures, David Kirschner Productions, Weimaraner Republic Pictures',
#   'Distributed by': 'Disney+',
#   'Release date': 'September 30, 2022',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 103,
#   'Budget (float)': 40000000.0,
#   'Box office (float)': ''},
#  {'Title': 'Disenchanted',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/9/93/Disenchanted.jpg',
#   'Directed by': ['Adam Shankman'],
#   'Directors url': ['/wiki/Adam_Shankman'],
#   'Screenplay by': 'Brigitte Hales',
#   'Story by': 'J. David Stem, David N. Weiss, Richard LaGravenese',
#   'Based on': 'Characters by Bill Kelly',
#   'Produced by': 'Barry Josephson, Barry Sonnenfeld, Amy Adams',
#   'Starring': 'Amy Adams, Patrick Dempsey, Maya Rudolph, Yvette Nicole Brown, Jayma Mays, Gabriella Baldacchino, Idina Menzel, James Marsden',
#   'Cinematography': 'Simon Duggan',
#   'Edited by': 'Emma E. Hickox, Chris Lebenzon',
#   'Music by': 'Alan Menken',
#   'Production companies': 'Walt Disney Pictures, Josephson Entertainment, Right Coast Productions',
#   'Distributed by': 'Disney+ Walt Disney Studios Motion Pictures',
#   'Release dates': 'November 16, 2022',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 119,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Strange World',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/f/fe/Strange_World_poster.jpg',
#   'Directed by': ['Don Hall'],
#   'Directors url': ['/wiki/Don_Hall_(filmmaker)'],
#   'Written by': 'Qui Nguyen',
#   'Produced by': 'Roy Conli',
#   'Starring': 'Jake Gyllenhaal, Dennis Quaid, Jaboukie Young-White, Gabrielle Union, Lucy Liu',
#   'Cinematography': 'Tracy Scott Beattie, Brian Leach',
#   'Edited by': 'Sarah K. Reimers',
#   'Music by': 'Henry Jackman',
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'November 15, 2022',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 102,
#   'Budget (float)': 135000000.0,
#   'Box office (float)': 73600000.0},
#  {'Title': 'Diary of a Wimpy Kid: Rodrick Rules',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/72/Diary_of_a_Wimpy_Kid_Rodrick_Rules_2022_poster.jpeg/220px-Diary_of_a_Wimpy_Kid_Rodrick_Rules_2022_poster.jpeg',
#   'Directed by': [],
#   'Directors url': [],
#   'Screenplay by': 'Jeff Kinney',
#   'Based on': 'Diary of a Wimpy Kid: Rodrick Rules by Jeff Kinney',
#   'Produced by': 'Jeff Kinney',
#   'Starring': 'Hunter Dillon, Brady Noon, Ethan William Childress, Chris Diamantopoulos, Erica Cerra',
#   'Edited by': 'Sylvain Blais, Rob Levesque, Matthew Sipple',
#   'Music by': 'John Paesano',
#   'Production companies': 'Walt Disney Pictures, Bardel Entertainment',
#   'Distributed by': 'Disney+',
#   'Release date': 'December 2, 2022',
#   'Countries': 'United States, Canada',
#   'Language': 'English',
#   'Running time (int)': 75,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Night at the Museum: Kahmunrah Rises Again',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b6/Night_at_the_Museum-_Kahmunrah_Rises_Again.webp/220px-Night_at_the_Museum-_Kahmunrah_Rises_Again.webp.png',
#   'Directed by': ['Matt Danner'],
#   'Directors url': ['/wiki/Matt_Danner'],
#   'Written by': 'Ray DeLaurentis, William Schifrin',
#   'Based on': 'The Night at the Museum by Milan Trenc',
#   'Produced by': 'Shawn Levy',
#   'Starring': 'Joshua Bassett, Jamie Demetriou, Alice Isaaz, Gillian Jacobs, Joseph Kamal, Thomas Lennon, Zachary Levi, Alexander Salamat, Kieran Sequoia, Jack Whitehall, Bowen Yang, Steve Zahn',
#   'Edited by': 'Luc Perrault',
#   'Music by': 'John Paesano',
#   'Production companies': 'Walt Disney Pictures, 21 Laps Entertainment, Atomic Cartoons, Alibaba Pictures',
#   'Distributed by': 'Disney+ Alibaba Pictures',
#   'Release date': 'December 9, 2022',
#   'Countries': 'United States, Canada, China',
#   'Language': 'English',
#   'Running time (int)': 77,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Chang Can Dunk',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/78/Chang_can_dunk.png/220px-Chang_can_dunk.png',
#   'Directed by': [],
#   'Directors url': [],
#   'Written by': 'Jingyi Shao',
#   'Produced by': 'Rishi Rajani, Lena Waithe, Brad Weston, Negin Salmasi',
#   'Starring': 'Bloom Li, Dexter Darden, Ben Wang, Zoe Renee, Chase Liefeld, Mardy Ma, Eric Anthony Lopez',
#   'Cinematography': 'Ross Riege',
#   'Edited by': 'Brad Turner',
#   'Music by': 'Nathan Matthew David',
#   'Production companies': 'Walt Disney Pictures, Hillman Grad Productions, Makeready',
#   'Distributed by': 'Disney+',
#   'Release date': 'March 10, 2023',
#   'Country': 'United States',
#   'Languages': 'English, Mandarin',
#   'Running time (int)': 109,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Peter Pan & Wendy',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/1/1f/Peter_Pan_%26_Wendy_poster.png/220px-Peter_Pan_%26_Wendy_poster.png',
#   'Directed by': ['David Lowery'],
#   'Directors url': ['/wiki/David_Lowery_(director)'],
#   'Screenplay by': 'David Lowery, Toby Halbrooks',
#   'Based on': "Walt Disney 's Peter Pan Peter and Wendy by J. M. Barrie",
#   'Produced by': 'Jim Whitaker',
#   'Starring': 'Jude Law, Alexander Molony, Ever Anderson, Yara Shahidi, Alyssa Wapanatâhk, Joshua Pickering, Jacobi Jupe, Jim Gaffigan',
#   'Cinematography': 'Bojan Bazelli',
#   'Edited by': 'Lisa Zeno Churgin',
#   'Music by': 'Daniel Hart',
#   'Production companies': 'Walt Disney Pictures, Whitaker Entertainment',
#   'Distributed by': 'Disney+',
#   'Release date': 'April 28, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 109,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Crater',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/41/Crater_film_poster.png/220px-Crater_film_poster.png',
#   'Directed by': ['Kyle Patrick Alvarez'],
#   'Directors url': ['/wiki/Kyle_Patrick_Alvarez'],
#   'Written by': 'John Griffin',
#   'Produced by': 'Dan Cohen, Dan Levine, Shawn Levy',
#   'Starring': 'Isaiah Russell-Bailey, Mckenna Grace, Billy Barratt, Orson Hong, Thomas Boyce, Scott Mescudi',
#   'Cinematography': 'Jas Shelton',
#   'Edited by': 'James W. Harrison III',
#   'Music by': 'Dan Romer, Osei Essed',
#   'Production companies': 'Walt Disney Pictures, 21 Laps Entertainment',
#   'Distributed by': 'Disney+',
#   'Release date': 'May 12, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 105,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'The Little Mermaid',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f4/The_Little_Mermaid_%282023_film%29.png/220px-The_Little_Mermaid_%282023_film%29.png',
#   'Directed by': ['Rob Marshall'],
#   'Directors url': ['/wiki/Rob_Marshall'],
#   'Screenplay by': 'David Magee',
#   'Based on': '" The Little Mermaid " by Hans Christian Andersen Disney \'s The Little Mermaid by Ron Clements John Musker',
#   'Produced by': 'Marc Platt, Lin-Manuel Miranda, John DeLuca, Rob Marshall',
#   'Starring': 'Halle Bailey, Jonah Hauer-King, Daveed Diggs, Awkwafina, Jacob Tremblay, Noma Dumezweni, Art Malik, Javier Bardem, Melissa McCarthy',
#   'Cinematography': 'Dion Beebe',
#   'Edited by': 'Wyatt Smith',
#   'Music by': 'Alan Menken',
#   'Production companies': 'Walt Disney Pictures, DeLuca Marshall, Marc Platt Productions',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'May 8, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 135,
#   'Budget (float)': 240200000.0,
#   'Box office (float)': 569600000.0},
#  {'Title': 'Elemental',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/4d/Elemental_final_poster.jpg/220px-Elemental_final_poster.jpg',
#   'Directed by': ['Peter Sohn'],
#   'Directors url': ['/wiki/Peter_Sohn'],
#   'Screenplay by': 'Kat Likkel, John Hoberg, Brenda Hsueh',
#   'Story by': 'Peter Sohn, John Hoberg, Kat Likkel, Brenda Hsueh',
#   'Produced by': 'Denise Ream',
#   'Starring': "Leah Lewis, Mamoudou Athie, Ronnie del Carmen, Shila Ommi, Wendi McLendon-Covey, Catherine O'Hara",
#   'Cinematography': 'David Bianchi, Jean-Claude Kalache',
#   'Edited by': 'Stephen Schaffer',
#   'Music by': 'Thomas Newman',
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'May 27, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 101,
#   'Budget (float)': 200000000.0,
#   'Box office (float)': 496400000.0},
#  {'Title': "World's Best",
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/cf/World%27s_Best_2023_film.jpg/220px-World%27s_Best_2023_film.jpg',
#   'Directed by': [],
#   'Directors url': [],
#   'Written by': 'Utkarsh Ambudkar, Jamie King',
#   'Produced by': 'Thomas Kail, Utkarsh Ambudkar, Kate Sullivan',
#   'Starring': 'Utkarsh Ambudkar, Manny Magnus, Punam Patel',
#   'Cinematography': 'Sing Howe Yam',
#   'Edited by': 'Jonah Moran',
#   'Music by': 'Jongnic Bontemps, Raashi Kulkarni',
#   'Production company': 'Walt Disney Pictures',
#   'Distributed by': 'Disney+',
#   'Release date': 'June 23, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 101,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Indiana Jones and the Dial of Destiny',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c3/Indiana_Jones_and_the_Dial_of_Destiny_theatrical_poster.jpg/220px-Indiana_Jones_and_the_Dial_of_Destiny_theatrical_poster.jpg',
#   'Directed by': ['James Mangold'],
#   'Directors url': ['/wiki/James_Mangold'],
#   'Written by': 'Jez Butterworth, John-Henry Butterworth, David Koepp, James Mangold',
#   'Based on': 'Characters by George Lucas Philip Kaufman',
#   'Produced by': 'Kathleen Kennedy, Frank Marshall, Simon Emanuel',
#   'Starring': 'Harrison Ford, Phoebe Waller-Bridge, Antonio Banderas, John Rhys-Davies, Toby Jones, Boyd Holbrook, Ethann Isidore, Mads Mikkelsen',
#   'Cinematography': 'Phedon Papamichael',
#   'Edited by': 'Michael McCusker, Andrew Buckland, Dirk Westervelt',
#   'Music by': 'John Williams',
#   'Production companies': 'Walt Disney Pictures, Lucasfilm Ltd.',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'May 18, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 154,
#   'Budget (float)': 295000000.0,
#   'Box office (float)': 384000000.0},
#  {'Title': 'Haunted Mansion',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/3/31/Haunted_Mansion_%282023%29_poster.jpg/220px-Haunted_Mansion_%282023%29_poster.jpg',
#   'Directed by': ['Justin Simien'],
#   'Directors url': ['/wiki/Justin_Simien'],
#   'Screenplay by': 'Katie Dippold',
#   'Based on': 'The Haunted Mansion by Walt Disney',
#   'Produced by': 'Dan Lin, Jonathan Eirich',
#   'Starring': 'LaKeith Stanfield, Tiffany Haddish, Owen Wilson, Danny DeVito, Rosario Dawson, Dan Levy, Jamie Lee Curtis, Jared Leto',
#   'Cinematography': 'Jeffrey Waldron',
#   'Edited by': 'Phillip J. Bartell',
#   'Music by': 'Kris Bowers',
#   'Production companies': 'Walt Disney Pictures, Rideback',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'July 15, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 123,
#   'Budget (float)': 150000000.0,
#   'Box office (float)': 117500000.0},
#  {'Title': 'Dashing Through the Snow',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Dashing_through_the_snow_poster.jpg/220px-Dashing_through_the_snow_poster.jpg',
#   'Directed by': ['Tim Story'],
#   'Directors url': ['/wiki/Tim_Story'],
#   'Written by': 'Scott Rosenberg',
#   'Produced by': 'John Jacobs, Will Packer',
#   'Starring': 'Lil Rel Howery, Chris "Ludacris" Bridges, Teyonah Parris, Oscar Nunez, Madison Skye Validum, Mary Lynn Rajskub',
#   'Cinematography': 'Chris Duskin',
#   'Edited by': 'David Clark, David Rennie',
#   'Music by': 'Christopher Lennertz',
#   'Production companies': 'Walt Disney Pictures, Will Packer Productions, Smart Entertainment',
#   'Distributed by': 'Disney+',
#   'Release date': 'November 17, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 90,
#   'Budget (float)': '',
#   'Box office (float)': ''},
#  {'Title': 'Wish',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/de/WishMoviePoster.jpg/220px-WishMoviePoster.jpg',
#   'Directed by': ['Chris Buck', 'Fawn Veerasunthorn'],
#   'Directors url': ['/wiki/Chris_Buck', '/wiki/Fawn_Veerasunthorn'],
#   'Screenplay by': 'Jennifer Lee, Allison Moore',
#   'Story by': 'Jennifer Lee, Chris Buck, Fawn Veerasunthorn, Allison Moore',
#   'Produced by': 'Peter Del Vecho, Juan Pablo Reyes Lancaster-Jones',
#   'Starring': 'Ariana DeBose, Chris Pine, Alan Tudyk, Angelique Cabral, Victor Garber, Natasha Rothwell, Jennifer Kumiyama, Harvey Guillén, Evan Peters, Ramy Youssef, Jon Rudnitsky',
#   'Cinematography': 'Rob Dressel, Adolph Lusinsky',
#   'Edited by': 'Jeff Draheim',
#   'Music by': 'Dave Metzger,, Julia Michaels,, Benjamin Rice',
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Release dates': 'November 8, 2023',
#   'Country': 'United States',
#   'Language': 'English',
#   'Running time (int)': 95,
#   'Budget (float)': 175000000.0,
#   'Box office (float)': 254900000.0},
#  {'Title': 'Diary of a Wimpy Kid Christmas: Cabin Fever',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c0/Diary_of_a_Wimpy_Kid_Christmas_Cabin_Fever_poster.jpg/220px-Diary_of_a_Wimpy_Kid_Christmas_Cabin_Fever_poster.jpg',
#   'Directed by': [],
#   'Directors url': [],
#   'Screenplay by': 'Jeff Kinney',
#   'Based on': 'Diary of a Wimpy Kid: Cabin Fever by Jeff Kinney',
#   'Produced by': 'Jeff Kinney',
#   'Starring': 'Wesley Kimmel, Spencer Howell, Erica Cerra, Hunter Dillon, Chris Diamantopoulos',
#   'Music by': 'John Paesano',
#   'Production companies': 'Walt Disney Pictures, Bardel Entertainment',
#   'Distributed by': 'Disney+',
#   'Release date': 'December 8, 2023',
#   'Countries': 'United States, Canada',
#   'Language': 'English',
#   'Running time (int)': 62,
#   'Budget (float)': '',
#   'Box office (float)': ''}]

# %% [markdown]
# #### removes comma from date string

# %%
for movie in movie_info_list:
    date_str = movie.get('Release date', "")
    if date_str.endswith(","):
        movie['Release date'] = date_str[:-1]

# %%
print([movie.get('Release date') for movie in movie_info_list if movie.get('Release date', "").startswith('2')])
# Out:
# ['2009', '22 April 2011', '25 May 2012', '23 December 2021']

# %%
# new_dataset = []
# for movie in dataset:
#     movie = {k.replace("Release dates", "Release date"): v for k, v in movie.items()}
#     movie = {k.replace("Original release", "Release date"): v for k, v in movie.items()}
#     new_dataset.append(movie)

# %%
from datetime import datetime
def reformat_date(date_str):
    # Convert string to date
    date_object = datetime.strptime(date_str, '%d %B %Y')

    # Convert date to the desired format
    formatted_date = date_object.strftime('%B %d, %Y')
    return formatted_date

for movie in movie_info_list:
    date_str = movie.get('Release date', "")
    if date_str.startswith('1') or date_str.startswith('2'):
        movie['Release date']  = reformat_date(date_str=date_str)

# %%
save_json('cleaned_movies.json', movie_info_list)

# %%
# import datetime
# pattern1 = r'(\w+)\s(\d{1,2}),?\s(\d{4})'
# pattern2 = r'(\d{1,2})\s(\w+),?\s(\d{4})'
# pattern_code = {pattern1:[1, 2, 3], pattern2:[2, 1, 3]}

# def convert_to_datetime(date_text, code):
#     cleaned_date_text = f'{date_text.group(code[0])} {int(date_text.group(code[1])):02} {date_text.group(code[2])}'
#     return datetime.datetime.strptime(cleaned_date_text, '%B %d %Y').date()

# def get_date_text(x):
#     if x == 'N/A' or x==[]:
#         return 'N/A'
#     if isinstance(x, list):
# #         date_text = None
#         for pattern in pattern_code.keys():
#             date_text = re.search(pattern, x[0], flags=re.I)
#             if date_text:
#                 return convert_to_datetime(date_text, pattern_code[pattern])
                
#     if isinstance(x,str):
#         for pattern in pattern_code.keys():
#             date_text = re.search(pattern, x, flags=re.I)
#             if date_text:
#                 return convert_to_datetime(date_text, pattern_code[pattern])

# %%
# for movie in new_dataset:
#     movie['Release date (datetime)'] = get_date_text(movie.get('Release date', 'N/A'))
