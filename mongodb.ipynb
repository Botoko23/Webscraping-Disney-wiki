# %%
from pymongo.mongo_client import MongoClient
from dotenv import dotenv_values

import json
import pprint
import certifi

# %%
password = dotenv_values(".env")['MONGO_PWD']

uri = f"mongodb+srv://adminuser:{password}@playground.ypblo18.mongodb.net/?retryWrites=true&w=majority&appName=playground"

client = MongoClient(uri, serverSelectionTimeoutMS=5000, tlsCAFile=certifi.where())
# Out:
# storeMydata
# Traceback (most recent call last):
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 1272, in _get_socket
#     sock_info = self.sockets.popleft()
#                 ^^^^^^^^^^^^^^^^^^^^^^
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 1180, in connect
#     sock = _configured_socket(self.address, self.opts)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 988, in _configured_socket
#     sock = _create_connection(address, options)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 972, in _create_connection
#     raise err
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 965, in _create_connection
#     sock.connect(sa)
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/mongo_client.py", line 1741, in _process_kill_cursors
#     self._kill_cursors(
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/mongo_client.py", line 1687, in _kill_cursors
#     with server.get_socket(self.__all_credentials) as sock_info:
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 1225, in get_socket
#     sock_info = self._get_socket(all_credentials)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 1275, in _get_socket
#     sock_info = self.connect(all_credentials)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 1187, in connect
#     _raise_connection_failure(self.address, error)
#   File "/Users/trihoang/Desktop/Disney/venv/lib/python3.11/site-packages/pymongo/pool.py", line 277, in _raise_connection_failure
#     raise NetworkTimeout(msg)
# pymongo.errors.NetworkTimeout: ac-9u4yhke-shard-00-01.ypblo18.mongodb.net:27017: [Errno 60] Operation timed out

# %%
names = client.list_database_names()
print(names)
# Out:
# ['disney', 'admin', 'local']

# %%
disney_db = client.disney
disney_db.list_collection_names()
# Out:
# ['movies', 'directors']

# %%
movies_collection = disney_db.movies
directors_collection = disney_db.directors

# %%
def load_json(title:str):
    with open(title, encoding='utf-8') as f:
        return json.loads(f.read())
    
movie_info_list = load_json('dataset/cleaned_movies.json')
director_info_list = load_json('dataset/directors.json')

# %%
batch_size = 10
for i in range(0, len(director_info_list), batch_size):
    batch = director_info_list[i:i + batch_size]
    directors_collection.insert_many(batch)
print('done inserting directors')

batch_size = 10
for i in range(0, len(movie_info_list), batch_size):
    batch = movie_info_list[i:i + batch_size]
    movies_collection.insert_many(batch)
print('done inserting movies')
# Out:
# done inserting directors
# done inserting movies

# %% [markdown]
# ## Analysis

# %%
# 1. Count the number of movies directed by each director:
    # {"$rename": { "_id": "Director" } }. Cant use renanme in aggregate pipeline
    # the id in $group needs to be there
count_movies_by_director = movies_collection.aggregate([
    {"$unwind": "$Directed by"},
    {"$group": { "_id": "$Directed by", "num of movies": { "$sum": 1 } }},
    {"$addFields": { "Director": "$_id" }},
    {"$sort": {"num of movies": -1}},
    {"$project": {"_id": 0}},
    {"$limit": 10}
])

pprint.pprint(list(count_movies_by_director))
# Out:
# [{'Director': 'Robert Stevenson', 'num of movies': 19},
#  {'Director': 'Norman Tokar', 'num of movies': 15},
#  {'Director': 'Hamilton Luske', 'num of movies': 13},
#  {'Director': 'Vincent McEveety', 'num of movies': 13},
#  {'Director': 'James Algar', 'num of movies': 12},
#  {'Director': 'Clyde Geronimi', 'num of movies': 11},
#  {'Director': 'Wilfred Jackson', 'num of movies': 11},
#  {'Director': 'Jack Kinney', 'num of movies': 10},
#  {'Director': 'Wolfgang Reitherman', 'num of movies': 8},
#  {'Director': 'Alastair Fothergill', 'num of movies': 8}]

# %%
# 2. Find the movie with the highest box office collection:
highest_box_office_movie = movies_collection.find({'Box office (float)': {"$ne": "" }}).sort([("Box office (float)", -1)]).limit(1)
pprint.pprint(list(highest_box_office_movie))
# Out:
# [{'Based on': "Disney 's The Lion King",
#   'Box office (float)': 1663000000.0,
#   'Budget (float)': 250000000.0,
#   'Cinematography': 'Caleb Deschanel',
#   'Country': 'United States',
#   'Directed by': ['Jon Favreau'],
#   'Directors url': ['/wiki/Jon_Favreau'],
#   'Distributed by': 'Walt Disney Studios Motion Pictures',
#   'Edited by': 'Mark Livolsi, Adam Gerstel',
#   'Language': 'English',
#   'Music by': 'Hans Zimmer',
#   'Poster': 'https://upload.wikimedia.org/wikipedia/en/9/9d/Disney_The_Lion_King_2019.jpg',
#   'Produced by': 'Jon Favreau, Jeffrey Silver, Karen Gilchrist',
#   'Production companies': 'Walt Disney Pictures, Fairview Entertainment',
#   'Release dates': 'July 9, 2019',
#   'Running time (int)': 118,
#   'Screenplay by': 'Jeff Nathanson',
#   'Starring': 'Donald Glover, Seth Rogen, Chiwetel Ejiofor, Alfre Woodard, '
#               'Billy Eichner, John Kani, John Oliver, Beyoncé Knowles-Carter, '
#               'James Earl Jones',
#   'Title': 'The Lion King',
#   '_id': ObjectId('66266a7f42e6e752c3d6e9ba')}]

# %%
# 3. Find if movie is profitable?
document = movies_collection.find_one()

# Extract field names
field_names = document.keys()

is_profitable = movies_collection.aggregate([
  {"$match": {
      "$and": [
        { "Box office (float)": { "$type": "double" } },
        { "Budget (float)": { "$type": "double" } }
      ]
    }
  },
  {
    "$addFields": {
      "Profit": { "$subtract": ["$Box office (float)", "$Budget (float)"] }
    }
  },
  {
    "$addFields": {
      "Is_profitable": {
        "$switch": {
          "branches": [
            { "case": { "$gte": ["$Profit", 0]}, "then": "Profitable" }
          ],
          "default": "Loss"
        }
      }
    }
  },
  {"$project": {field : 0 for field in field_names if field not in ['Title', 'Box office (float)', 'Budget (float)', 'Profit', 'Is_profitable']}}
])

pprint.pprint(list(is_profitable))
# Out:
# [{'Box office (float)': 960000.0,
#   'Budget (float)': 600000.0,
#   'Profit': 360000.0,
#   'Title': 'The Reluctant Dragon',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Dumbo, the Flying Elephant by Helen Aberson Harold Pearl',
#   'Box office (float)': 1300000.0,
#   'Budget (float)': 950000.0,
#   'Narrated by': 'John McLeish',
#   'Profit': 350000.0,
#   'Release dates': 'October 23, 1941',
#   'Story by': 'Joe Grant, Dick Huemer',
#   'Title': 'Dumbo',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Victory Through Air Power by Maj. Alexander P. Seversky',
#   'Box office (float)': 799000.0,
#   'Budget (float)': 788000.0,
#   'Narrated by': 'Art Baker',
#   'Profit': 11000.0,
#   'Title': 'Victory Through Air Power',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Adventures of Pinocchio by Carlo Collodi',
#   'Box office (float)': 164000000.0,
#   'Budget (float)': 2600000.0,
#   'Profit': 161400000.0,
#   'Release dates': 'February 7, 1940',
#   'Story by': 'Ted Sears, Otto Englander, Webb Smith, William Cottrell, Joseph '
#               'Sabo, Erdman Penner, Aurelius Battaglia',
#   'Title': 'Pinocchio',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Snow White " by the Brothers Grimm',
#   'Box office (float)': 418000000.0,
#   'Budget (float)': 1500000.0,
#   'Profit': 416500000.0,
#   'Release dates': 'December 21, 1937',
#   'Story by': 'Ted Sears, Richard Creedon, Otto Englander, Dick Rickard, Earl '
#               'Hurd, Merrill De Maris, Dorothy Ann Blank, Webb Smith',
#   'Title': 'Snow White and the Seven Dwarfs',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 76400000.0,
#   'Budget (float)': 2280000.0,
#   'Profit': 74120000.0,
#   'Story by': 'Joe Grant, Dick Huemer',
#   'Title': 'Fantasia',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Bambi, a Life in the Woods by Felix Salten',
#   'Box office (float)': 267399999.99999997,
#   'Budget (float)': 858000.0,
#   'Profit': 266541999.99999997,
#   'Release dates': 'August 9, 1942',
#   'Story by': 'Perce Pearce, Larry Morey, Vernon Stallings, Melvin Shaw, Carl '
#               'Fallberg, Chuck Couch, Ralph Wright',
#   'Title': 'Bambi',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Casey at the Bat " by Ernest Thayer Peter and the Wolf by '
#               'Sergei Prokofiev',
#   'Box office (float)': 3275000.0,
#   'Budget (float)': 1350000.0,
#   'Profit': 1925000.0,
#   'Release dates': 'April 20, 1946',
#   'Story by': 'James Bodrero, Homer Brightman, Erwin Graham, Eric Gurney, T. '
#               'Hee, Sylvia Holland, Dick Huemer, Dick Kelsey, Dick Kinney, '
#               'Jesse Marsh, Tom Oreb, Cap Palmer, Erdman Penner, Dick Shaw, '
#               'Harry Reeves, John Walbridge, Roy Williams',
#   'Title': 'Make Mine Music',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Cinderella " by Charles Perrault',
#   'Box office (float)': 182000000.0,
#   'Budget (float)': 2200000.0,
#   'Profit': 179800000.0,
#   'Release dates': 'February 15, 1950',
#   'Story by': 'William Peet, Ted Sears, Homer Brightman, Kenneth Anderson, '
#               'Erdman Penner, Winston Hibler, Harry Reeves, Joe Rinaldi',
#   'Title': 'Cinderella',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 2560000.0,
#   'Budget (float)': 1500000.0,
#   'Profit': 1060000.0,
#   'Story by': 'Winston Hibler, Erdman Penner, Harry Reeves, Homer Brightman, '
#               'Ken Anderson, Ted Sears, Joe Rinaldi, Bill Cottrell, Art Scott, '
#               'Jesse Marsh, Bob Moore, John Walbridge',
#   'Title': 'Melody Time',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Uncle Remus " by Joel Chandler Harris',
#   'Box office (float)': 65000000.0,
#   'Budget (float)': 2125000.0,
#   'Profit': 62875000.0,
#   'Release dates': 'November 12, 1946',
#   'Screenplay by': 'Morton Grant, Maurice Rapf, Dalton S. Reymond, Bill Peet, '
#                    'George Stallings, Ralph Wright',
#   'Title': 'Song of the South',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Alice's Adventures in Wonderland and Through the Looking-Glass "
#               'by Lewis Carroll',
#   'Box office (float)': 2400000.0,
#   'Budget (float)': 3000000.0,
#   'Profit': -600000.0,
#   'Release dates': 'July 26, 1951',
#   'Story by': 'Winston Hibler, Ted Sears, Bill Peet, Erdman Penner, Joe '
#               'Rinaldi, Milt Banta, Bill Cottrell, Dick Kelsey, Joe Grant, '
#               'Dick Huemer, Del Connell, Tom Oreb, John Walbridge',
#   'Title': 'Alice in Wonderland',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Treasure Island by Robert Louis Stevenson',
#   'Box office (float)': 4099999.9999999995,
#   'Budget (float)': 1800000.0,
#   'Countries': 'United States, United Kingdom',
#   'Profit': 2299999.9999999995,
#   'Release dates': 'June 22, 1950',
#   'Title': 'Treasure Island',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Midnight and Jeremiah by Sterling North',
#   'Box office (float)': 4500000.0,
#   'Budget (float)': 1500000.0,
#   'Profit': 3000000.0,
#   'Release dates': 'November 29, 1948 (Chicago)',
#   'Title': 'So Dear to My Heart',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Peter and Wendy by J. M. Barrie',
#   'Box office (float)': 87400000.0,
#   'Budget (float)': 4000000.0,
#   'Narrated by': 'Tom Conway',
#   'Profit': 83400000.0,
#   'Story by': 'Ted Sears, Erdman Penner, Bill Peet, Winston Hibler, Joe '
#               'Rinaldi, Milt Banta, Ralph Wright, Bill Cottrell',
#   'Title': 'Peter Pan',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Twenty Thousand Leagues Under the Seas by Jules Verne',
#   'Box office (float)': 28200000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 23200000.0,
#   'Screenplay by': 'Earl Felton',
#   'Title': '20,000 Leagues Under the Sea',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'When Knighthood Was in Flower by Charles Major James B. Fagan',
#   'Box office (float)': 1000000.0,
#   'Budget (float)': 2000000.0,
#   'Countries': 'United Kingdom, United States',
#   'Profit': -1000000.0,
#   'Screenplay by': 'Lawrence Edward Watkin',
#   'Title': 'The Sword and the Rose',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 2600000.0,
#   'Budget (float)': 300000.0,
#   'Narrated by': 'Winston Hibler',
#   'Profit': 2300000.0,
#   'Title': 'The Living Desert',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '"Happy Dan, the Cynical Dog" by Ward Greene',
#   'Box office (float)': 187000000.0,
#   'Budget (float)': 4000000.0,
#   'Profit': 183000000.0,
#   'Story by': 'Erdman Penner, Joe Rinaldi, Ralph Wright, Don DaGradi, Joe '
#               'Grant',
#   'Title': 'Lady and the Tramp',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 1050000.0,
#   'Budget (float)': 1800000.0,
#   'Countries': 'United Kingdom, United States',
#   'Profit': -750000.0,
#   'Release dates': '26 October 1953',
#   'Title': 'Rob Roy: The Highland Rogue',
#   'sIs_profitable': 'Loss'},
#  {'Based on': '" Sleeping Beauty " by Charles Perrault',
#   'Box office (float)': 51600000.0,
#   'Budget (float)': 6000000.0,
#   'Profit': 45600000.0,
#   'Story by': 'Erdman Penner, Joe Rinaldi, Winston Hibler, Bill Peet, Ted '
#               'Sears, Ralph Wright, Milt Banta',
#   'Title': 'Sleeping Beauty',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Banner in the Sky 1954 novel by James Ramsey Ullman',
#   'Box office (float)': 1700000.0,
#   'Budget (float)': 2000000.0,
#   'Profit': -300000.0,
#   'Title': 'Third Man on the Mountain',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Pollyanna by Eleanor Porter',
#   'Box office (float)': 3750000.0,
#   'Budget (float)': 2500000.0,
#   'Profit': 1250000.0,
#   'Screenplay by': 'David Swift',
#   'Title': 'Pollyanna',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Swiss Family Robinson by Johann David Wyss',
#   'Box office (float)': 40000000.0,
#   'Budget (float)': 4000000.0,
#   'Profit': 36000000.0,
#   'Title': 'Swiss Family Robinson',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Hundred and One Dalmatians by Dodie Smith',
#   'Box office (float)': 303000000.0,
#   'Budget (float)': 3600000.0,
#   'Profit': 299400000.0,
#   'Screenplay by': 'Bill Peet,',
#   'Story by': 'Bill Peet',
#   'Title': 'One Hundred and One Dalmatians',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Hound of Florence by Felix Salten',
#   'Box office (float)': 12300000.0,
#   'Budget (float)': 1000000.0,
#   'Narrated by': 'Paul Frees',
#   'Profit': 11300000.0,
#   'Screenplay by': 'Lillie Hayward, Bill Walsh',
#   'Title': 'The Shaggy Dog',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Bon Voyage! by Joseph & Merrjane Hayes',
#   'Box office (float)': 5000000.0,
#   'Budget (float)': 3000000.0,
#   'Profit': 2000000.0,
#   'Screenplay by': 'Bill Walsh',
#   'Title': 'Bon Voyage!',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Babes in Toyland by Victor Herbert and Glen MacDonough',
#   'Box office (float)': 4600000.0,
#   'Budget (float)': 3000000.0,
#   'Profit': 1600000.0,
#   'Screenplay by': 'Lowell S. Hawley, Ward Kimball, Joe Rinaldi',
#   'Title': 'Babes in Toyland',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Sword in the Stone by T. H. White',
#   'Box office (float)': 22200000.0,
#   'Budget (float)': 3000000.0,
#   'Profit': 19200000.0,
#   'Release dates': 'December 12, 1963',
#   'Story by': 'Bill Peet',
#   'Title': 'The Sword in the Stone',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Mary Poppins by P. L. Travers',
#   'Box office (float)': 103100000.0,
#   'Budget (float)': 4400000.0,
#   'Profit': 98700000.0,
#   'Release dates': 'August 27, 1964',
#   'Screenplay by': 'Bill Walsh, Don DaGradi',
#   'Title': 'Mary Poppins',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Jungle Book by Rudyard Kipling',
#   'Box office (float)': 378000000.0,
#   'Budget (float)': 4000000.0,
#   'Profit': 374000000.0,
#   'Story by': 'Larry Clemmons, Ralph Wright, Ken Anderson, Vance Gerry',
#   'Title': 'The Jungle Book',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'My Philadelphia Father by Cordelia Drexel Biddle',
#   'Box office (float)': 5000000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 0.0,
#   'Release dates': 'June 23, 1967',
#   'Screenplay by': 'A. J. Carothers',
#   'Story by': 'A. J. Carothers',
#   'Title': 'The Happiest Millionaire',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '"The Aristocats" by Tom McGowan Tom Rowe',
#   'Box office (float)': 191000000.0,
#   'Budget (float)': 4000000.0,
#   'Profit': 187000000.0,
#   'Release dates': 'December 11, 1970',
#   'Story by': 'Ken Anderson, Larry Clemmons, Eric Cleworth, Vance Gerry, '
#               'Julius Svendsen, Frank Thomas, Ralph Wright',
#   'Title': 'The Aristocats',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '"Car, Boy, Girl" by Gordon Buford',
#   'Box office (float)': 51200000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 46200000.0,
#   'Release dates': 'December 24, 1968',
#   'Screenplay by': 'Bill Walsh, Don DaGradi',
#   'Title': 'The Love Bug',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Magic Bedknob & Bonfires and Broomsticks by Mary Norton',
#   'Box office (float)': 17900000.0,
#   'Budget (float)': 6300000.0,
#   'Profit': 11600000.0,
#   'Release dates': 'October 7, 1971',
#   'Screenplay by': 'Bill Walsh, Don DaGradi',
#   'Title': 'Bedknobs and Broomsticks',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 10000000.0,
#   'Budget (float)': 8000000.0,
#   'Languages': 'English, Swedish, Norwegian, Danish, Icelandic',
#   'Profit': 2000000.0,
#   'Title': 'The Island at the Top of the World',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The legend of Robin Hood',
#   'Box office (float)': 33000000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 28000000.0,
#   'Story by': 'Larry Clemmons, Ken Anderson, Vance Gerry, Frank Thomas, Eric '
#               'Cleworth, Julius Svendsen, David Michener',
#   'Title': 'Robin Hood',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Rescuers Miss Bianca by Margery Sharp',
#   'Box office (float)': 169000000.0,
#   'Budget (float)': 7500000.0,
#   'Profit': 161500000.0,
#   'Story by': 'Larry Clemmons, Vance Gerry, Ken Anderson, Frank Thomas, Burny '
#               'Mattinson, Fred Lucky, Dick Sebast, David Michener, Ted Berman',
#   'Title': 'The Rescuers',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Freaky Friday by Mary Rodgers',
#   'Box office (float)': 36000000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 31000000.0,
#   'Release dates': 'December 17, 1976',
#   'Screenplay by': 'Mary Rodgers',
#   'Title': 'Freaky Friday',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "A Connecticut Yankee in King Arthur's Court ; novel by Mark "
#               'Twain',
#   'Box office (float)': 4475000.0,
#   'Budget (float)': 5250000.0,
#   'Countries': 'United Kingdom, United States',
#   'Profit': -775000.0,
#   'Release dates': 'July 19, 1979 (London)',
#   'Title': 'Unidentified Flying Oddball',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 35800000.0,
#   'Budget (float)': 20000000.0,
#   'Profit': 15800000.0,
#   'Release dates': 'December 18, 1979',
#   'Screenplay by': 'Gerry Day, Jeb Rosebrook',
#   'Story by': 'Jeb Rosebrook, Bob Barbash, Richard Landau',
#   'Title': 'The Black Hole',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 37000000.0,
#   'Budget (float)': 10000000.0,
#   'Profit': 27000000.0,
#   'Screenplay by': 'Malcolm Marmorstein',
#   'Story by': 'Seton I. Miller, S. S. Field',
#   'Title': "Pete's Dragon",
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '"The Gremlin\'s Castle" by Ernest K. Gann',
#   'Box office (float)': 11000000.0,
#   'Budget (float)': 6.0,
#   'Profit': 10999994.0,
#   'Title': "The Last Flight of Noah's Ark",
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 14100000.0,
#   'Budget (float)': 18000000.0,
#   'Production companies': 'Paramount Pictures, Walt Disney Productions',
#   'Profit': -3900000.0,
#   'Title': 'Dragonslayer',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'A Watcher in the Woods by Florence Engel Randall',
#   'Box office (float)': 5000000.0,
#   'Budget (float)': 9000000.0,
#   'Countries': 'United States, United Kingdom',
#   'Profit': -4000000.0,
#   'Release dates': 'April 17, 1980',
#   'Screenplay by': 'Brian Clemens, Harry Spalding, Rosemary Anne Sisson',
#   'Title': 'The Watcher in the Woods',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 2900000.0,
#   'Budget (float)': 4500000.0,
#   'Profit': -1600000.0,
#   'Title': 'Midnight Madness',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Popeye by E. C. Segar',
#   'Box office (float)': 60000000.0,
#   'Budget (float)': 20000000.0,
#   'Production companies': 'Paramount Pictures, Walt Disney Productions, Robert '
#                           'Evans Productions, King Features',
#   'Profit': 40000000.0,
#   'Release dates': 'December 6, 1980',
#   'Screenplay by': 'Jules Feiffer',
#   'Title': 'Popeye',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Fox and the Hound by Daniel P. Mannix',
#   'Box office (float)': 63500000.0,
#   'Budget (float)': 12000000.0,
#   'Profit': 51500000.0,
#   'Story by': 'Larry Clemmons, Ted Berman, David Michener, Peter Young, Burny '
#               'Mattinson, Steve Hulett, Earl Kress, Vance Gerry',
#   'Title': 'The Fox and the Hound',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Something Wicked This Way Comes by Ray Bradbury',
#   'Box office (float)': 8400000.0,
#   'Budget (float)': 20000000.0,
#   'Production companies': 'Walt Disney Productions, The Bryna Company',
#   'Profit': -11600000.0,
#   'Screenplay by': 'Ray Bradbury',
#   'Title': 'Something Wicked This Way Comes',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Never Cry Wolf by Farley Mowat',
#   'Box office (float)': 27600000.0,
#   'Budget (float)': 11000000.0,
#   'Languages': 'English, Inuktitut',
#   'Production companies': 'Walt Disney Pictures, Amarok Productions Ltd.',
#   'Profit': 16600000.0,
#   'Release dates': 'October 7, 1983 (limited)',
#   'Screenplay by': 'Curtis Hanson, Sam Hamm, Richard Kletter',
#   'Title': 'Never Cry Wolf',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Marvelous Land of Oz and Ozma of Oz by L. Frank Baum',
#   'Box office (float)': 11100000.0,
#   'Budget (float)': 28000000.0,
#   'Countries': 'United States, United Kingdom',
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners',
#   'Profit': -16900000.0,
#   'Screenplay by': 'Walter Murch, Gill Dennis',
#   'Title': 'Return to Oz',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Tex by S. E. Hinton',
#   'Box office (float)': 7400000.0,
#   'Budget (float)': 5000000.0,
#   'Profit': 2400000.0,
#   'Screenplay by': 'Charles S. Haas, Tim Hunter',
#   'Title': 'Tex',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 50000000.0,
#   'Budget (float)': 17000000.0,
#   'Production companies': 'Walt Disney Productions, Lisberger-Kushner '
#                           'Productions',
#   'Profit': 33000000.0,
#   'Screenplay by': 'Steven Lisberger',
#   'Story by': 'Steven Lisberger, Bonnie MacBird',
#   'Title': 'Tron',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 8000000.0,
#   'Budget (float)': 10000000.0,
#   'Countries': 'United Kingdom, United States',
#   'Profit': -2000000.0,
#   'Title': 'Night Crossing',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 9700000.0,
#   'Budget (float)': 8000000.0,
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners II',
#   'Profit': 1700000.0,
#   'Title': 'The Journey of Natty Gann',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 4304286.0,
#   'Budget (float)': 8000000.0,
#   'Profit': -3695714.0,
#   'Title': 'Trenchcoat',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'The Book of Three and The Black Cauldron by Lloyd Alexander',
#   'Box office (float)': 21300000.0,
#   'Budget (float)': 44000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Productions, '
#                           'Silver Screen Partners II',
#   'Profit': -22700000.0,
#   'Story by': 'Ted Berman, Vance Gerry, Joe Hale, David Jonas, Roy Morita, '
#               'Richard Rich, Art Stevens, Al Wilson, Peter Young',
#   'Title': 'The Black Cauldron',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 13000000.0,
#   'Budget (float)': 7500000.0,
#   'Countries': 'United States, Canada',
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners II, '
#                           'Telefilm Canada',
#   'Profit': 5500000.0,
#   'Screenplay by': 'Thomas Meehan',
#   'Story by': 'Thomas Meehan, Phillip Borsos, Barry Healey',
#   'Title': 'One Magic Christmas',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 13687027.0,
#   'Budget (float)': 8700000.0,
#   'Production companies': 'Burrowes Film Group, The Hoyts Group, Silver Screen '
#                           'Partners III',
#   'Profit': 4987027.0,
#   'Release dates': '24 March 1988',
#   'Title': 'The Man from Snowy River II',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Basil of Baker Street by Eve Titus Paul Galdone',
#   'Box office (float)': 38700000.0,
#   'Budget (float)': 14000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature '
#                           'Animation, Silver Screen Partners II',
#   'Profit': 24700000.0,
#   'Story by': 'Pete Young, Vance Gerry, Steve Hulett, Ron Clements, John '
#               "Musker, Bruce M. Morris, Matthew O'Callaghan, Burny Mattinson, "
#               'Dave Michener, Melvin Shaw',
#   'Title': 'The Great Mouse Detective',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 18600000.0,
#   'Budget (float)': 9000000.0,
#   'Production companies': 'PSO Productions, Viking Film AS',
#   'Profit': 9600000.0,
#   'Screenplay by': 'Michael Burton, Matt MacManus',
#   'Story by': 'Mark H. Baker',
#   'Title': 'Flight of the Navigator',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'DuckTales by Jymn Magon',
#   'Box office (float)': 18100000.0,
#   'Budget (float)': 20000000.0,
#   'Production companies': 'Walt Disney Pictures, Disney MovieToons, Walt '
#                           'Disney Animation France',
#   'Profit': -1900000.0,
#   'Screenplay by': 'Alan Burnett',
#   'Title': 'DuckTales the Movie: Treasure of the Lost Lamp',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Oliver Twist by Charles Dickens',
#   'Box office (float)': 121000000.0,
#   'Budget (float)': 31000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature '
#                           'Animation, Silver Screen Partners III',
#   'Profit': 90000000.0,
#   'Screenplay by': 'Jim Cox, Timothy J. Disney, James Mangold',
#   'Story by': 'Vance Gerry, Mike Gabriel, Joe Ranft, Jim Mitchell, Chris '
#               'Bailey, Kirk Wise, Dave Michener, Roger Allers, Gary Trousdale, '
#               'Kevin Lima, Michael Cedeno, Pete Young, Leon Joosen',
#   'Title': 'Oliver & Company',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Cheetahs by Alan Caillou',
#   'Box office (float)': 8153677.0,
#   'Budget (float)': 5000000.0,
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners III',
#   'Profit': 3153677.0,
#   'Screenplay by': 'Erik Tarloff, John Cotter, Griff Du Rhone',
#   'Story by': 'John Cotter',
#   'Title': 'Cheetah',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 222700000.0,
#   'Budget (float)': 18000000.0,
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners III',
#   'Profit': 204700000.0,
#   'Screenplay by': 'Ed Naha, Tom Schulman',
#   'Story by': 'Stuart Gordon, Brian Yuzna, Ed Naha',
#   'Title': 'Honey, I Shrunk the Kids',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 17000000.0,
#   'Budget (float)': 8700000.0,
#   'Countries': 'Norway, Sweden, United States',
#   'Languages': 'Norwegian, English',
#   'Production companies': 'Walt Disney Pictures, AB Svensk Filmindustri',
#   'Profit': 8300000.0,
#   'Release dates': '3 October 1990',
#   'Title': 'Shipwrecked',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Aladdin and the Magic Lamp " from One Thousand and One Nights',
#   'Box office (float)': 504100000.0,
#   'Budget (float)': 28000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 476100000.0,
#   'Screenplay by': 'Ron Clements, John Musker, Ted Elliott, Terry Rossio',
#   'Story by': 'Burny Mattinson, Roger Allers, Daan Jippes, Kevin Harkey, Sue '
#               'Nichols, Francis Glebas, Darrell Rooney, Larry Leker, James '
#               'Fujii, Kirk Hanson, Kevin Lima, Rebecca Rees, David S. Smith, '
#               'Chris Sanders, Brian Pimental, Patrick A. Ventura',
#   'Title': 'Aladdin',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'White Fang by Jack London',
#   'Box office (float)': 41000000.0,
#   'Budget (float)': 14000000.0,
#   'Production companies': 'Walt Disney Pictures, Silver Screen Partners IV',
#   'Profit': 27000000.0,
#   'Screenplay by': 'Jeanne Rosenberg, Nick Thiel, David Fallon',
#   'Title': 'White Fang',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Characters by Stuart Gordon Brian Yuzna Ed Naha',
#   'Box office (float)': 96000000.0,
#   'Budget (float)': 32000000.0,
#   'Production companies': 'Walt Disney Pictures, Touchwood Pacific Partners',
#   'Profit': 64000000.0,
#   'Screenplay by': 'Garry Goodrow, Thom Eberhardt, Peter Elbling',
#   'Story by': 'Garry Goodrow',
#   'Title': 'Honey, I Blew Up the Kid',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" Beauty and the Beast " by Jeanne-Marie Leprince de Beaumont',
#   'Box office (float)': 424000000.0,
#   'Budget (float)': 25000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature '
#                           'Animation, Silver Screen Partners IV',
#   'Profit': 399000000.0,
#   'Release dates': 'September 29, 1991',
#   'Screenplay by': 'Linda Woolverton',
#   'Story by': 'Brenda Chapman, Chris Sanders, Burny Mattinson, Kevin Harkey, '
#               'Brian Pimental, Bruce Woodside, Joe Ranft, Tom Ellery, Kelly '
#               'Asbury, Robert Lence',
#   'Title': 'Beauty and the Beast',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 50800000.0,
#   'Budget (float)': 14000000.0,
#   'Production companies': 'Walt Disney Pictures, Avnet–, Kerner, Productions, '
#                           'Touchwood Pacific Partners',
#   'Profit': 36800000.0,
#   'Title': 'The Mighty Ducks',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'A Christmas Carol by Charles Dickens',
#   'Box office (float)': 27200000.0,
#   'Budget (float)': 12000000.0,
#   'Production companies': 'Walt Disney Pictures, Jim Henson Productions',
#   'Profit': 15200000.0,
#   'Screenplay by': 'Jerry Juhl',
#   'Title': 'The Muppet Christmas Carol',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Rocketeer by Dave Stevens',
#   'Box office (float)': 46700000.0,
#   'Budget (float)': 35000000.0,
#   'Production companies': 'Walt Disney Pictures, Touchstone Pictures, Silver '
#                           'Screen Partners IV, Gordon Company',
#   'Profit': 11700000.0,
#   'Screenplay by': 'Danny Bilson, Paul De Meo',
#   'Story by': 'Danny Bilson, Paul De Meo, William Dear',
#   'Title': 'The Rocketeer',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 2800000.0,
#   'Budget (float)': 15000000.0,
#   'Production companies': 'Walt Disney Pictures, Touchwood Pacific Partners I',
#   'Profit': -12200000.0,
#   'Title': 'Newsies',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 154900000.0,
#   'Budget (float)': 17000000.0,
#   'Profit': 137900000.0,
#   'Screenplay by': 'Lynn Siefert, Tommy Swerdlow, Michael Goldberg',
#   'Story by': 'Lynn Siefert, Michael Ritchie',
#   'Title': 'Cool Runnings',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 50700000.0,
#   'Budget (float)': 28000000.0,
#   'Profit': 22700000.0,
#   'Screenplay by': 'Mick Garris, Neil Cuthbert',
#   'Story by': 'David Kirschner, Mick Garris',
#   'Title': 'Hocus Pocus',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Adventures of Huckleberry Finn by Mark Twain',
#   'Box office (float)': 24100000.0,
#   'Budget (float)': 11000000.0,
#   'Profit': 13100000.0,
#   'Screenplay by': 'Stephen Sommers',
#   'Title': 'The Adventures of Huck Finn',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Three Musketeers 1844 novel by Alexandre Dumas',
#   'Box office (float)': 111000000.0,
#   'Budget (float)': 30000000.0,
#   'Countries': 'United States, Austria',
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures',
#   'Profit': 81000000.0,
#   'Screenplay by': 'David Loughery',
#   'Title': 'The Three Musketeers',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 39000000.0,
#   'Budget (float)': 13000000.0,
#   'Profit': 26000000.0,
#   'Title': 'Blank Check',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 968400000.0,
#   'Budget (float)': 45000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 923400000.0,
#   'Screenplay by': 'Irene Mecchi, Jonathan Roberts, Linda Woolverton',
#   'Story by': 'Barry Johnson, Andy Gaskill, Kevin Harkey, Tom Sito, Rick Maki, '
#               'Burny Mattinson, Lorna Cook, Gary Trousdale, Jorgen Klubien, '
#               'Larry Leker, Ed Gombert, Mark Kausler, Thom Enriquez, Jim '
#               'Capobianco, Chris Sanders, Joe Ranft, Francis Glebas',
#   'Title': 'The Lion King',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Angels in the Outfield 1951 film by Dorothy Kingsley George '
#               'Wells Richard Conlin',
#   'Box office (float)': 50200000.0,
#   'Budget (float)': 31000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures',
#   'Profit': 19200000.0,
#   'Screenplay by': 'Holly Goldberg Sloan',
#   'Title': 'Angels in the Outfield',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Jungle Book and The Second Jungle Book by Rudyard Kipling',
#   'Box office (float)': 70000000.0,
#   'Budget (float)': 30000000.0,
#   'Production companies': 'Vegahom Europe, Baloo Productions, Jungle Book '
#                           'Films',
#   'Profit': 40000000.0,
#   'Screenplay by': 'Stephen Sommers, Ronald Yanover, Mark Geldman',
#   'Story by': 'Ronald Yanover, Mark Geldman',
#   'Title': "Rudyard Kipling's The Jungle Book",
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 8199999.999999999,
#   'Budget (float)': 32000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures',
#   'Profit': -23800000.0,
#   'Title': 'Tall Tale',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 190300000.0,
#   'Budget (float)': 22000000.0,
#   'Production companies': 'Walt Disney Pictures, Hollywood Pictures, Outlaw '
#                           'Productions',
#   'Profit': 168300000.0,
#   'Release dates': 'November 5, 1994',
#   'Title': 'The Santa Clause',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 40070995.0,
#   'Budget (float)': 22000000.0,
#   'Narrated by': 'Jonathan Taylor Thomas',
#   'Production companies': 'Walt Disney Pictures, All Girl Productions, Orr & '
#                           'Cruickshank Productions',
#   'Profit': 18070995.0,
#   'Screenplay by': 'James Orr, Jim Cruickshank',
#   'Story by': 'David E. Peckinpah, Richard Jefferies',
#   'Title': 'Man of the House',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 13400000.0,
#   'Budget (float)': 15000000.0,
#   'Countries': 'United Kingdom, United States',
#   'Production companies': 'Trimark Pictures, Walt Disney Pictures, Tapestry '
#                           'Films',
#   'Profit': -1600000.0,
#   'Title': "A Kid in King Arthur's Court",
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 17700000.0,
#   'Budget (float)': 12000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures',
#   'Profit': 5700000.0,
#   'Title': 'The Big Green',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 394400000.0,
#   'Budget (float)': 30000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 364400000.0,
#   'Release dates': 'November 19, 1995',
#   'Screenplay by': 'Joss Whedon, Andrew Stanton, Joel Cohen, Alec Sokolow',
#   'Story by': 'John Lasseter, Pete Docter, Andrew Stanton, Joe Ranft',
#   'Title': 'Toy Story',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Goof Troop by Robert Taylor Michael Peraza Jr. Goofy by Art '
#               'Babbitt Frank Webb',
#   'Box office (float)': 37600000.0,
#   'Budget (float)': 18000000.0,
#   'Production companies': 'Walt Disney Pictures, Disney MovieToons, Walt '
#                           'Disney Television Animation',
#   'Profit': 19600000.0,
#   'Screenplay by': 'Jymn Magon, Chris Matheson, Brian Pimental',
#   'Story by': 'Jymn Magon',
#   'Title': 'A Goofy Movie',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Pocahontas',
#   'Box office (float)': 346100000.0,
#   'Budget (float)': 55000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 291100000.0,
#   'Release dates': 'June 10, 1995',
#   'Story by': 'Glen Keane, Joe Grant, Ralph Zondag, Burny Mattinson, Ed '
#               'Gombert, Kaan Kalyon, Francis Glebas, Robert Gibbs, Bruce '
#               'Morris, Todd Kurosawa, Duncan Marjoribanks, Chris Buck',
#   'Title': 'Pocahontas',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 24670346.0,
#   'Budget (float)': 24000000.0,
#   'Languages': 'English, Vietnamese',
#   'Production companies': 'Walt Disney Pictures, Interscope Communications, '
#                           'PolyGram Filmed Entertainment',
#   'Profit': 670346.0,
#   'Screenplay by': 'Gene Quintano, Jim Kouf',
#   'Story by': 'Jim Morris',
#   'Title': 'Operation Dumbo Drop',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Hunchback of Notre-Dame by Victor Hugo',
#   'Box office (float)': 325300000.0,
#   'Budget (float)': 70000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 255300000.0,
#   'Release dates': 'June 19, 1996',
#   'Screenplay by': 'Tab Murphy, Irene Mecchi, Bob Tzudiker, Noni White, '
#                    'Jonathan Roberts',
#   'Story by': 'Tab Murphy',
#   'Title': 'The Hunchback of Notre Dame',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'James and the Giant Peach by Roald Dahl',
#   'Box office (float)': 37700000.0,
#   'Budget (float)': 38000000.0,
#   'Countries': 'United Kingdom, United States',
#   'Production companies': 'Walt Disney Pictures, Allied Filmmakers, '
#                           'Skellington Productions',
#   'Profit': -300000.0,
#   'Release dates': 'April 12, 1996',
#   'Screenplay by': 'Karey Kirkpatrick, Jonathan Roberts, Steve Bloom',
#   'Title': 'James and the Giant Peach',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 59900000.0,
#   'Budget (float)': 32000000.0,
#   'Countries': 'United States, France',
#   'Production companies': 'Walt Disney Pictures, TF1 International',
#   'Profit': 27900000.0,
#   'Release dates': 'March 7, 1997',
#   'Title': 'Jungle 2 Jungle',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Heracles',
#   'Box office (float)': 252700000.0,
#   'Budget (float)': 85000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 167700000.0,
#   'Screenplay by': 'Ron Clements, John Musker, Donald McEnery, Bob Shaw, Irene '
#                    'Mecchi',
#   'Story by': 'Kaan Kalyon, Kelly Wightman, Randy Cartwright, John Ramirez, '
#               'Jeff Snow, Vance Gerry, Kirk Hanson, Francis Glebas, Mark '
#               'Kennedy, Bruce M. Morris, Don Dougherty, Thom Enriquez',
#   'Title': 'Hercules',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Hundred and One Dalmatians by Dodie Smith',
#   'Box office (float)': 320700000.0,
#   'Budget (float)': 67000000.0,
#   'Production companies': 'Walt Disney Pictures, Great Oaks Entertainment',
#   'Profit': 253700000.0,
#   'Release dates': 'November 18, 1996',
#   'Title': '101 Dalmatians',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 26465920.0,
#   'Budget (float)': 15000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures, Roger '
#                           'Birnbaum Productions',
#   'Profit': 11465920.0,
#   'Title': 'First Kid',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'George of the Jungle by Jay Ward Bill Scott',
#   'Box office (float)': 174400000.0,
#   'Budget (float)': 55000000.0,
#   'Profit': 119400000.0,
#   'Screenplay by': 'Dana Olsen, Audrey Wells',
#   'Story by': 'Dana Olsen',
#   'Title': 'George of the Jungle',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '"A Situation of Gravity" by Samuel W. Taylor',
#   'Box office (float)': 178000000.0,
#   'Budget (float)': 80000000.0,
#   'Profit': 98000000.0,
#   'Release dates': 'November 16, 1997',
#   'Title': 'Flubber',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 15400000.0,
#   'Budget (float)': 16000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures, Roger '
#                           'Birnbaum Productions',
#   'Profit': -600000.0,
#   'Title': 'RocketMan',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 4400000.0,
#   'Budget (float)': 24000000.0,
#   'Production companies': 'Walt Disney Pictures, DIC Entertainment, Peak '
#                           'Productions',
#   'Profit': -19600000.0,
#   'Title': 'Meet the Deedles',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 27800000.0,
#   'Budget (float)': 3000000.0,
#   'Countries': 'United States, Canada',
#   'Production companies': 'Keystone Pictures, Buddy Films, Inc.',
#   'Profit': 24800000.0,
#   'Title': 'Air Bud',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Mr. Magoo by Millard Kaufman and John Hubley',
#   'Box office (float)': 28900000.0,
#   'Budget (float)': 30000000.0,
#   'Production companies': 'Walt Disney Pictures, UPA Productions',
#   'Profit': -1100000.0,
#   'Title': 'Mr. Magoo',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Ballad of Mulan by Guo Maoqian',
#   'Box office (float)': 304300000.0,
#   'Budget (float)': 90000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 214300000.0,
#   'Release dates': 'June 5, 1998',
#   'Screenplay by': 'Rita Hsiao, Chris Sanders, Philip LaZebnik, Raymond '
#                    'Singer, Eugenia Bostwick-Singer',
#   'Story by': 'Robert D. San Souci',
#   'Title': 'Mulan',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Lisa and Lottie by Erich Kästner',
#   'Box office (float)': 92100000.0,
#   'Budget (float)': 15000000.0,
#   'Profit': 77100000.0,
#   'Release dates': 'July 20, 1998',
#   'Screenplay by': 'David Swift, Nancy Meyers, Charles Shyer',
#   'Title': 'The Parent Trap',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'My Favorite Martian by John L. Greene',
#   'Box office (float)': 36800000.0,
#   'Budget (float)': 65000000.0,
#   'Profit': -28200000.0,
#   'Title': 'My Favorite Martian',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Mighty Joe Young by Merian C. Cooper Ruth Rose',
#   'Box office (float)': 50600000.0,
#   'Budget (float)': 90000000.0,
#   'Production companies': 'Walt Disney Pictures, RKO Pictures, The Jacobson '
#                           'Company',
#   'Profit': -39400000.0,
#   'Screenplay by': 'Mark Rosenthal, Lawrence Konner',
#   'Title': 'Mighty Joe Young',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Doug by Jim Jinkins',
#   'Box office (float)': 19400000.0,
#   'Budget (float)': 5000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Television '
#                           'Animation, Jumbo Pictures',
#   'Profit': 14400000.0,
#   'Title': "Doug's 1st Movie",
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 363300000.0,
#   'Budget (float)': 40000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 323300000.0,
#   'Release dates': 'November 14, 1998',
#   'Screenplay by': 'Andrew Stanton, Donald McEnery, Bob Shaw',
#   'Story by': 'John Lasseter, Andrew Stanton, Joe Ranft',
#   'Title': "A Bug's Life",
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 12200000.0,
#   'Budget (float)': 30000000.0,
#   'Production companies': 'Walt Disney Pictures, Mandeville Films',
#   'Profit': -17800000.0,
#   'Screenplay by': 'Tom Nursall, Harris Goldberg',
#   'Story by': 'Michael Allin',
#   'Title': "I'll Be Home for Christmas",
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 511400000.0,
#   'Budget (float)': 90000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 421400000.0,
#   'Release dates': 'November 13, 1999',
#   'Screenplay by': 'Andrew Stanton, Rita Hsiao, Doug Chamberlin, Chris Webb',
#   'Story by': 'John Lasseter, Pete Docter, Ash Brannon, Andrew Stanton',
#   'Title': 'Toy Story 2',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 90900000.0,
#   'Budget (float)': 80000000.0,
#   'Profit': 10900000.0,
#   'Release dates': 'December 17, 1999',
#   'Title': 'Fantasia 2000',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Inspector Gadget by Bruno Bianchi Jean Chalopin Andy Heyward',
#   'Box office (float)': 134400000.0,
#   'Budget (float)': 75000000.0,
#   'Production companies': 'Walt Disney Pictures, Caravan Pictures, DIC '
#                           'Entertainment, Avnet/Kerner Productions, Roger '
#                           'Birnbaum Productions',
#   'Profit': 59400000.0,
#   'Screenplay by': 'Kerry Ehrin, Zak Penn',
#   'Story by': 'Kerry Ehrin, Dana Olsen',
#   'Title': 'Inspector Gadget',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 6400000.0,
#   'Budget (float)': 10000000.0,
#   'Countries': 'United States, United Kingdom, France',
#   'Production companies': 'Asymmetrical Productions, Canal+, FilmFour, Ciby '
#                           '2000, Le Studio Canal+',
#   'Profit': -3600000.0,
#   'Release dates': 'May 21, 1999',
#   'Title': 'The Straight Story',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Characters created by A. A. Milne',
#   'Box office (float)': 96200000.0,
#   'Budget (float)': 20000000.0,
#   'Countries': 'United States, Japan',
#   'Production companies': 'Walt Disney Television Animation, Walt Disney '
#                           'Animation Japan, Walt Disney Pictures',
#   'Profit': 76200000.0,
#   'Screenplay by': 'Jun Falkenstein',
#   'Story by': 'Eddie Guzelian',
#   'Title': 'The Tigger Movie',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 500000.0,
#   'Budget (float)': 4000000.0,
#   'Profit': -3500000.0,
#   'Screenplay by': 'Dereck Joubert, Jordan Moffet, Holly Goldberg Sloan',
#   'Story by': 'Dereck Joubert, Beverly Joubert',
#   'Title': "Whispers: An Elephant's Tale",
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Tarzan of the Apes by Edgar Rice Burroughs',
#   'Box office (float)': 448200000.0,
#   'Budget (float)': 130000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 318200000.0,
#   'Release dates': 'June 12, 1999',
#   'Screenplay by': 'Tab Murphy, Bob Tzudiker, Noni White',
#   'Story by': 'Stephen Anderson, Mark D. Kennedy, Carole Holliday, Gaëtan '
#               'Brizzi, Paul Brizzi, Don Dougherty, Ed Gombert, Randy Haycock, '
#               'Don Hall, Kevin L. Harkey, Glen Keane, Burny Mattinson, Frank '
#               'Nissen, John Norton, Jeff Snow, Michael Surrey, Christopher J. '
#               'Ure, Mark Walton, Stevie Wermers, Kelly Wightman, John Ramirez',
#   'Title': 'Tarzan',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 110300000.0,
#   'Budget (float)': 65000000.0,
#   'Production companies': 'Walt Disney Pictures, Junction Entertainment',
#   'Profit': 45300000.0,
#   'Title': 'The Kid',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Hundred and One Dalmatians by Dodie Smith',
#   'Box office (float)': 183600000.0,
#   'Budget (float)': 85000000.0,
#   'Production companies': 'Walt Disney Pictures, Cruella Productions, Kanzaman '
#                           'S.A.M. Films',
#   'Profit': 98600000.0,
#   'Screenplay by': 'Kristen Buckley, Brian Regan, Bob Tzudiker, Noni White',
#   'Story by': 'Kristen Buckley, Brian Regan',
#   'Title': '102 Dalmatians',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 186100000.0,
#   'Budget (float)': 90000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 96100000.0,
#   'Release dates': 'June 3, 2001',
#   'Screenplay by': 'Tab Murphy',
#   'Story by': 'Kirk Wise, Gary Trousdale, Joss Whedon, Bryce Zabel, Jackie '
#               'Zabel, Tab Murphy',
#   'Title': 'Atlantis: The Lost Empire',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 136800000.0,
#   'Budget (float)': 30000000.0,
#   'Production companies': 'Walt Disney Pictures, Jerry Bruckheimer Films, '
#                           'Technical Black Films',
#   'Profit': 106800000.0,
#   'Title': 'Remember the Titans',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Recess by Paul Germain Joe Ansolabehere',
#   'Box office (float)': 44500000.0,
#   'Budget (float)': 23000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Television '
#                           'Animation, Paul, &, Joe, Productions',
#   'Profit': 21500000.0,
#   'Release dates': 'February 10, 2001',
#   'Screenplay by': 'Jonathan Greenberg',
#   'Story by': 'Joe Ansolabehere, Paul Germain, Jonathan Greenberg',
#   'Title': "Recess: School's Out",
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 349800000.0,
#   'Budget (float)': 127500000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature '
#                           'Animation, The Secret Lab',
#   'Profit': 222300000.0,
#   'Release dates': 'May 13, 2000',
#   'Screenplay by': 'John Harrison, Robert Nelson Jacobs, Walon Green',
#   'Story by': 'Walon Green, John Harrison, Robert Nelson Jacobs, Thom '
#               'Enriquez, Ralph Zondag',
#   'Title': 'Dinosaur',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Original story by Roger Allers Matthew Jacobs',
#   'Box office (float)': 169700000.0,
#   'Budget (float)': 100000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 69700000.0,
#   'Release dates': 'December 10, 2000',
#   'Screenplay by': 'David Reynolds',
#   'Story by': 'Chris Williams, Mark Dindal',
#   'Title': "The Emperor's New Groove",
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Princess Diaries by Meg Cabot',
#   'Box office (float)': 165300000.0,
#   'Budget (float)': 26000000.0,
#   'Production companies': 'Walt Disney Pictures, BrownHouse Productions',
#   'Profit': 139300000.0,
#   'Release dates': 'July 29, 2001',
#   'Screenplay by': 'Gina Wendkos',
#   'Title': 'The Princess Diaries',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Characters created by J.M. Barrie',
#   'Box office (float)': 115100000.0,
#   'Budget (float)': 20000000.0,
#   'Countries': 'United States, Canada, Australia',
#   'Production companies': 'Walt Disney Pictures, Disney MovieToons, Walt '
#                           'Disney Television Animation',
#   'Profit': 95100000.0,
#   'Release dates': 'February 10, 2002',
#   'Screenplay by': 'Temple Mathews',
#   'Title': 'Return to Never Land',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 80700000.0,
#   'Budget (float)': 22000000.0,
#   'Production companies': 'Walt Disney Pictures, Gran Via',
#   'Profit': 58700000.0,
#   'Title': 'The Rookie',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 18600000.0,
#   'Budget (float)': 25000000.0,
#   'Production companies': 'Walt Disney Pictures, Karz Entertainment',
#   'Profit': -6400000.0,
#   'Screenplay by': 'Jonathan Bernstein, Mark Blackwell, James Greer',
#   'Story by': 'David Watts, Jonathan Bernstein, Mark Blackwell, James Greer',
#   'Title': "Max Keeble's Big Move",
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 115000000.0,
#   'Budget (float)': 33000000.0,
#   'Production companies': 'Walt Disney Pictures, The Kerner Entertainment '
#                           'Company',
#   'Profit': 82000000.0,
#   'Title': 'Snow Dogs',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 579700000.0,
#   'Budget (float)': 115000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 464700000.0,
#   'Release dates': 'October 28, 2001',
#   'Screenplay by': 'Andrew Stanton, Daniel Gerson',
#   'Story by': 'Pete Docter, Jill Culton, Jeff Pidgeon, Ralph Eggleston',
#   'Title': 'Monsters, Inc.',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 273100000.0,
#   'Budget (float)': 80000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': 193100000.0,
#   'Release dates': 'June 16, 2002',
#   'Story by': 'Chris Sanders',
#   'Title': 'Lilo & Stitch',
#   'sIs_profitable': 'Profitable'},
#  {'': '',
#   'Box office (float)': 395800000.0,
#   'Budget (float)': 19200000.0,
#   'Profit': 376600000.0,
#   'Revised Hepburn': 'Sen to Chihiro no Kamikakushi',
#   'Title': 'Spirited Away',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Tuck Everlasting by Natalie Babbitt',
#   'Box office (float)': 19300000.0,
#   'Budget (float)': 15000000.0,
#   'Production companies': 'Walt Disney Pictures, Scholastic Studios, Beacon '
#                           'Pictures',
#   'Profit': 4300000.0,
#   'Screenplay by': 'Jeffrey Lieber, James V. Hart',
#   'Title': 'Tuck Everlasting',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Treasure Island by Robert Louis Stevenson',
#   'Box office (float)': 109600000.0,
#   'Budget (float)': 140000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Feature Animation',
#   'Profit': -30400000.0,
#   'Release dates': 'November 6, 2002',
#   'Screenplay by': 'Ron Clements, John Musker, Rob Edwards',
#   'Story by': 'Ron Clements, John Musker, Ted Elliott, Terry Rossio',
#   'Title': 'Treasure Planet',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Characters created by Leo Benvenuti Steve Rudnick',
#   'Box office (float)': 172900000.0,
#   'Budget (float)': 65000000.0,
#   'Production companies': 'Walt Disney Pictures, Outlaw Productions, Boxing '
#                           'Cat Films',
#   'Profit': 107900000.0,
#   'Release dates': 'October 23, 2002',
#   'Screenplay by': 'Don Rhymer, Cinco Paul, Ken Daurio, Ed Decter, John J. '
#                    'Strauss',
#   'Story by': 'Leo Benvenuti, Steve Rudnick',
#   'Title': 'The Santa Clause 2',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 135700000.0,
#   'Budget (float)': 20000000.0,
#   'Countries': 'United States, Australia',
#   'Production companies': 'Walt Disney Pictures, DisneyToon Studios',
#   'Profit': 115700000.0,
#   'Title': 'The Jungle Book 2',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Walt Disney 's Country Bear Jamboree",
#   'Box office (float)': 18000000.0,
#   'Budget (float)': 35000000.0,
#   'Profit': -17000000.0,
#   'Title': 'The Country Bears',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Winnie the Pooh and The House at Pooh Corner created by A. A. '
#               'Milne',
#   'Box office (float)': 62900000.0,
# ...
#   'Screenplay by': 'Melissa Mathison',
#   'Title': 'The BFG',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 127400000.0,
#   'Budget (float)': 8000000.0,
#   'Narrated by': 'Charles Berling, Romane Bohringer, Jules Sitruk',
#   'Production companies': 'National Geographic Films, Bonne Pioche, Wild Bunch',
#   'Profit': 119400000.0,
#   'Release dates': '21 January 2005',
#   'Title': 'March of the Penguins',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Disney 's Beauty and the Beast by Linda Woolverton",
#   'Box office (float)': 1266000000.0,
#   'Budget (float)': 160000000.0,
#   'Production companies': 'Walt Disney Pictures, Mandeville Films',
#   'Profit': 1106000000.0,
#   'Release dates': 'February 23, 2017',
#   'Screenplay by': 'Stephen Chbosky, Evan Spiliotopoulos',
#   'Title': 'Beauty and the Beast',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 687200000.0,
#   'Budget (float)': 150000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 537200000.0,
#   'Release dates': 'November 14, 2016',
#   'Screenplay by': 'Jared Bush',
#   'Story by': 'Ron Clements, John Musker, Chris Williams, Don Hall, Pamela '
#               'Ribon, Aaron Kandell, Jordan Kandell',
#   'Title': 'Moana',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 814300000.0,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 639300000.0,
#   'Release dates': 'October 20, 2017',
#   'Screenplay by': 'Adrian Molina, Matthew Aldrich',
#   'Story by': 'Lee Unkrich, Jason Katz, Matthew Aldrich, Adrian Molina',
#   'Title': 'Coco',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Baba Yaga and Koschei',
#   'Box office (float)': 30500000.0,
#   'Budget (float)': 8000000.0,
#   'Languages': 'Russian, English',
#   'Production companies': 'Walt Disney Pictures CIS, Yellow, Black and White',
#   'Profit': 22500000.0,
#   'Screenplay by': 'Vitaliy Shlyappo, Dimitriy Yan, Pavel Danilov, Igor '
#                    'Tudvasev',
#   'Title': None,
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 383900000.0,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 208900000.0,
#   'Release dates': 'May 23, 2017',
#   'Screenplay by': 'Kiel Murray, Bob Peterson, Mike Rich',
#   'Story by': 'Brian Fee, Ben Queen, Eyal Podell, Jonathan E. Stewart',
#   'Title': 'Cars 3',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 35000.0,
#   'Budget (float)': 52000.0,
#   'Production companies': 'Walt Disney Pictures, Picture Shuru Entertainment',
#   'Profit': -17000.0,
#   'Story by': 'Anurag Basu',
#   'Title': 'Jagga Jasoos',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 1243000000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 1043000000.0,
#   'Release dates': 'June 5, 2018',
#   'Title': 'Incredibles 2',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "A Wrinkle in Time by Madeleine L'Engle",
#   'Box office (float)': 133199999.99999999,
#   'Budget (float)': 100000000.0,
#   'Production companies': 'Walt Disney Pictures, Whitaker Entertainment',
#   'Profit': 33199999.999999985,
#   'Release dates': 'February 26, 2018',
#   'Screenplay by': 'Jennifer Lee, Jeff Stockwell',
#   'Title': 'A Wrinkle in Time',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 25100000.0,
#   'Budget (float)': 5000000.0,
#   'Countries': 'United States, China, France',
#   'Languages': 'English, Mandarin, French',
#   'Narrated by': 'John Krasinski, Zhou Xun, Claire Keim',
#   'Production companies': 'Disneynature, Shanghai Media Group, Chuan Films, '
#                           'Brian Leith Productions',
#   'Profit': 20100000.0,
#   'Release dates': 'August 12, 2016',
#   'Screenplay by': 'David Fowler, Brian Leith, Phil Chapman, Lu Chuan',
#   'Simplified Chinese': '',
#   'Title': 'Born in China',
#   'Traditional Chinese': '',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Characters from Disney's Winnie the Pooh by A. A. Milne E. H. "
#               'Shepard',
#   'Box office (float)': 197700000.0,
#   'Budget (float)': 65.0,
#   'Production companies': 'Walt Disney Pictures, 2DUX² Productions',
#   'Profit': 197699935.0,
#   'Release dates': 'July 30, 2018',
#   'Screenplay by': 'Alex Ross Perry, Tom McCarthy, Allison Schroeder',
#   'Story by': 'Max Landis,, Greg Brooker, Mark Steven Johnson',
#   'Title': 'Christopher Robin',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Characters by Ted Elliott Terry Rossio Stuart Beattie Jay '
#               "Wolpert Walt Disney 's Pirates of the Caribbean",
#   'Box office (float)': 795900000.0,
#   'Budget (float)': 230000000.0,
#   'Production companies': 'Walt Disney Pictures, Jerry Bruckheimer Films',
#   'Profit': 565900000.0,
#   'Release dates': 'May 11, 2017',
#   'Screenplay by': 'Jeff Nathanson',
#   'Story by': 'Jeff Nathanson, Terry Rossio',
#   'Title': None,
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Disney 's The Lion King",
#   'Box office (float)': 1663000000.0,
#   'Budget (float)': 250000000.0,
#   'Production companies': 'Walt Disney Pictures, Fairview Entertainment',
#   'Profit': 1413000000.0,
#   'Release dates': 'July 9, 2019',
#   'Screenplay by': 'Jeff Nathanson',
#   'Title': 'The Lion King',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Mary Poppins by P. L. Travers',
#   'Box office (float)': 349500000.0,
#   'Budget (float)': 130000000.0,
#   'Production companies': 'Walt Disney Pictures, Lucamar Productions, Marc '
#                           'Platt Productions',
#   'Profit': 219500000.0,
#   'Release dates': 'November 29, 2018',
#   'Screenplay by': 'David Magee',
#   'Story by': 'David Magee, Rob Marshall, John DeLuca',
#   'Title': 'Mary Poppins Returns',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Characters from: Disney \'s Sleeping Beauty " La Belle au Bois '
#               'Dormant " by Charles Perrault',
#   'Box office (float)': 492200000.0,
#   'Budget (float)': 186000000.0,
#   'Production companies': 'Walt Disney Pictures, Roth/Kirschenbaum Films',
#   'Profit': 306200000.0,
#   'Release dates': 'September 30, 2019',
#   'Title': 'Maleficent: Mistress of Evil',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Disney 's Dumbo by Otto Englander Joe Grant Dick Huemer Dumbo, "
#               'the Flying Elephant by Helen Aberson Harold Pearl',
#   'Box office (float)': 353300000.0,
#   'Budget (float)': 170000000.0,
#   'Production companies': 'Walt Disney Pictures, Tim Burton Productions, '
#                           'Infinite Detective Productions, Secret Machine '
#                           'Entertainment',
#   'Profit': 183300000.0,
#   'Release dates': 'March 11, 2019',
#   'Screenplay by': 'Ehren Kruger',
#   'Title': 'Dumbo',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 529299999.99999994,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 354299999.99999994,
#   'Release dates': 'November 5, 2018',
#   'Screenplay by': 'Phil Johnston, Pamela Ribon',
#   'Story by': 'Rich Moore, Phil Johnston, Jim Reardon, Pamela Ribon, Josie '
#               'Trinidad',
#   'Title': 'Ralph Breaks the Internet',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" The Nutcracker and the Mouse King " by E. T. A. Hoffmann The '
#               'Nutcracker by Marius Petipa',
#   'Box office (float)': 174000000.0,
#   'Budget (float)': 120000000.0,
#   'Production companies': 'Walt Disney Pictures, The Mark Gordon Company',
#   'Profit': 54000000.0,
#   'Release dates': 'October 29, 2018',
#   'Title': 'The Nutcracker and the Four Realms',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 1073000000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 873000000.0,
#   'Release dates': 'June 11, 2019',
#   'Screenplay by': 'Andrew Stanton, Stephany Folsom',
#   'Story by': 'John Lasseter, Andrew Stanton, Josh Cooley, Valerie LaPointe, '
#               'Rashida Jones, Will McCormack, Martin Hynes, Stephany Folsom',
#   'Title': 'Toy Story 4',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 142000000.0,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': -33000000.0,
#   'Release dates': 'February 21, 2020',
#   'Screenplay by': 'Dan Scanlon, Jason Headley, Keith Bunin',
#   'Story by': 'Dan Scanlon, Keith Bunin, Jason Headley',
#   'Title': 'Onward',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 1453000000.0,
#   'Budget (float)': 150000000.0,
#   'Layouts by': 'Scott Beattie',
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 1303000000.0,
#   'Release dates': 'November 7, 2019',
#   'Screenplay by': 'Jennifer Lee',
#   'Story by': 'Jennifer Lee, Chris Buck, Marc Smith, Kristen Anderson-Lopez, '
#               'Robert Lopez',
#   'Title': 'Frozen 2',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Story ideas by Bradley Raymond and Helen Kalafatic',
#   'Box office (float)': 130400000.0,
#   'Budget (float)': 100000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 30400000.0,
#   'Screenplay by': 'Qui Nguyen, Adele Lim',
#   'Story by': 'Paul Briggs, Don Hall, Adele Lim, Carlos López Estrada, Kiel '
#               'Murray, Qui Nguyen, John Ripa, Dean Wellins',
#   'Title': 'Raya and the Last Dragon',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Disney's Mulan by Rita Hsiao Chris Sanders Philip LaZebnik "
#               'Raymond Singer Eugenia Bostwick-Singer Robert D. San Souci '
#               'Ballad of Mulan by Guo Maoqian',
#   'Box office (float)': 69900000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Jason T. Reed Productions, '
#                           'Good Fear Productions',
#   'Profit': -130100000.0,
#   'Release dates': 'March 9, 2020',
#   'Screenplay by': 'Rick Jaffa, Amanda Silver, Lauren Hynek, Elizabeth Martin',
#   'Title': 'Mulan',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 122200000.0,
#   'Budget (float)': 150000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': -27800000.0,
#   'Release dates': 'October 11, 2020',
#   'Title': 'Soul',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Russian: Bogatyr English: Hero or Warrior',
#   'Box office (float)': 28300000.0,
#   'Budget (float)': 7000000.0,
#   'Production companies': 'The Walt Disney Company CIS, Yellow, Black and '
#                           'White, Russia-1, Cinema Fund Russia',
#   'Profit': 21300000.0,
#   'Release dates': 'December 24, 2020',
#   'Title': 'The Last Warrior: Root of Evil',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Walt Disney 's Jungle Cruise",
#   'Box office (float)': 220900000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Davis Entertainment, Seven '
#                           'Bucks Productions, Flynn Picture Company',
#   'Profit': 20900000.0,
#   'Release dates': 'July 24, 2021',
#   'Screenplay by': 'Michael Green, Glenn Ficarra, John Requa',
#   'Story by': 'John Norville, Josh Goldstein, Glenn Ficarra, John Requa',
#   'Title': 'Jungle Cruise',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 21500000.0,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': -153500000.0,
#   'Release dates': 'March 1, 2022',
#   'Screenplay by': 'Julia Cho, Domee Shi',
#   'Story by': 'Domee Shi, Julia Cho, Sarah Streicher',
#   'Title': 'Turning Red',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'The Hundred and One Dalmatians by Dodie Smith',
#   'Box office (float)': 233.5,
#   'Budget (float)': 100000000.0,
#   'Production companies': 'Walt Disney Pictures, Marc Platt Productions, Gunn '
#                           'Films',
#   'Profit': -99999766.5,
#   'Release dates': 'May 18, 2021',
#   'Screenplay by': 'Dana Fox, Tony McNamara',
#   'Story by': 'Aline Brosh McKenna, Kelly Marcel, Steve Zissis',
#   'Title': 'Cruella',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 256800000.0,
#   'Budget (float)': 120000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 136800000.0,
#   'Release dates': 'November 3, 2021',
#   'Screenplay by': 'Charise Castro Smith, Jared Bush',
#   'Story by': 'Jared Bush, Byron Howard, Charise Castro Smith, Jason Hand, '
#               'Nancy Kruse, Lin-Manuel Miranda',
#   'Title': 'Encanto',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'Russian: Bogatyr English: Hero or Warrior',
#   'Box office (float)': 27000000.0,
#   'Budget (float)': 5000000.0,
#   'Production companies': 'Walt Disney Pictures, Buena Vista International, '
#                           'The Walt Disney Company CIS, Yellow, Black and '
#                           'White',
#   'Profit': 22000000.0,
#   'Title': 'The Last Warrior: Emissary of Darkness',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 226400000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 26400000.0,
#   'Release dates': 'June 8, 2022',
#   'Screenplay by': 'Jason Headley, Angus MacLane',
#   'Story by': 'Angus MacLane, Matthew Aldrich, Jason Headley',
#   'Title': 'Lightyear',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': "Chip 'n Dale: Rescue Rangers by Tad Stones Alan Zaslove Chip "
#               "'n' Dale by Bill Justice",
#   'Box office (float)': 623190.0,
#   'Budget (float)': 70000000.0,
#   'Production companies': 'Walt Disney Pictures, Mandeville Films, Lonely '
#                           'Island Classics,',
#   'Profit': -69376810.0,
#   'Release dates': 'May 16, 2022',
#   'Title': "Chip 'n Dale: Rescue Rangers",
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 73600000.0,
#   'Budget (float)': 135000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': -61400000.0,
#   'Release dates': 'November 15, 2022',
#   'Title': 'Strange World',
#   'sIs_profitable': 'Loss'},
#  {'Based on': 'Characters by George Lucas Philip Kaufman',
#   'Box office (float)': 384000000.0,
#   'Budget (float)': 295000000.0,
#   'Production companies': 'Walt Disney Pictures, Lucasfilm Ltd.',
#   'Profit': 89000000.0,
#   'Release dates': 'May 18, 2023',
#   'Title': 'Indiana Jones and the Dial of Destiny',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': '" The Little Mermaid " by Hans Christian Andersen Disney \'s '
#               'The Little Mermaid by Ron Clements John Musker',
#   'Box office (float)': 569600000.0,
#   'Budget (float)': 240200000.0,
#   'Production companies': 'Walt Disney Pictures, DeLuca Marshall, Marc Platt '
#                           'Productions',
#   'Profit': 329400000.0,
#   'Release dates': 'May 8, 2023',
#   'Screenplay by': 'David Magee',
#   'Title': 'The Little Mermaid',
#   'sIs_profitable': 'Profitable'},
#  {'Based on': 'The Haunted Mansion by Walt Disney',
#   'Box office (float)': 117500000.0,
#   'Budget (float)': 150000000.0,
#   'Production companies': 'Walt Disney Pictures, Rideback',
#   'Profit': -32500000.0,
#   'Release dates': 'July 15, 2023',
#   'Screenplay by': 'Katie Dippold',
#   'Title': 'Haunted Mansion',
#   'sIs_profitable': 'Loss'},
#  {'Box office (float)': 496400000.0,
#   'Budget (float)': 200000000.0,
#   'Production companies': 'Walt Disney Pictures, Pixar Animation Studios',
#   'Profit': 296400000.0,
#   'Release dates': 'May 27, 2023',
#   'Screenplay by': 'Kat Likkel, John Hoberg, Brenda Hsueh',
#   'Story by': 'Peter Sohn, John Hoberg, Kat Likkel, Brenda Hsueh',
#   'Title': 'Elemental',
#   'sIs_profitable': 'Profitable'},
#  {'Box office (float)': 254900000.0,
#   'Budget (float)': 175000000.0,
#   'Production companies': 'Walt Disney Pictures, Walt Disney Animation Studios',
#   'Profit': 79900000.0,
#   'Release dates': 'November 8, 2023',
#   'Screenplay by': 'Jennifer Lee, Allison Moore',
#   'Story by': 'Jennifer Lee, Chris Buck, Fawn Veerasunthorn, Allison Moore',
#   'Title': 'Wish',
#   'sIs_profitable': 'Profitable'}]

# %%
# Age of director now
director_age = directors_collection.aggregate([
  {"$match": { "Born": { "$ne": "Unknown" }}},
  {
    "$addFields": {
      "Born": {
        "$toDate": "$Born"
      }
    }
  },
  {
    "$addFields": {
      "Current Age": {
        "$dateDiff": {
            "startDate": "$Born",
            "endDate": "$$NOW",
            "unit": "year"
        }
      }
    }
  },
  {
    "$project": {
      "Director Name": 1, 
      "Current Age": 1,
      "Occupations": 1,
      "Years active": 1,
      "Spouse": 1,
      "Awards": 1,
      "_id": 0
    }
  }
])

pprint.pprint(list(director_age))
# Out:
# [{'Current Age': 81, 'Director Name': 'George Butler'},
#  {'Current Age': 63,
#   'Director Name': 'Andy Knight',
#   'Years active': '1990–2008'},
#  {'Current Age': 63,
#   'Director Name': 'Reginald Hudlin',
#   'Spouse': 'Chrisette Suter',
#   'Years active': '1983–present'},
#  {'Current Age': 56,
#   'Director Name': 'Donovan Cook',
#   'Years active': '1990–present'},
#  {'Current Age': 103, 'Director Name': 'Fletcher Markle'},
#  {'Current Age': 57,
#   'Director Name': 'Craig Gillespie',
#   'Years active': '1995–present'},
#  {'Current Age': 121, 'Director Name': 'Hamilton Luske'},
#  {'Current Age': None,
#   'Director Name': 'Brian Fee',
#   'Occupations': 'Storyboard artist, film director, voice actor',
#   'Years active': '1998–present'},
#  {'Awards': 'Academy Award, Annie Award, BAFTA Award',
#   'Current Age': 66,
#   'Director Name': 'Chris Buck',
#   'Spouse': 'Shelley Rae Hinton'},
#  {'Current Age': 58,
#   'Director Name': 'Andrew Adamson',
#   'Occupations': 'Film director, film producer, screenwriter, animator',
#   'Years active': '1990–present'},
#  {'Current Age': 78,
#   'Director Name': 'Lasse Hallström',
#   'Years active': '1973–present'},
#  {'Current Age': 64,
#   'Director Name': 'Gary Trousdale',
#   'Occupations': 'Animator, film director, screenwriter, storyboard artist',
#   'Years active': '1982–present'},
#  {'Current Age': 62,
#   'Director Name': 'Rob Minkoff',
#   'Occupations': 'Director, producer, animator',
#   'Spouse': 'Crystal Kung',
#   'Years active': '1985–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2011), BAFTA Award for '
#             'Best Animated Film, (2011)',
#   'Current Age': 60,
#   'Director Name': 'Gore Verbinski',
#   'Occupations': 'Film director, screenwriter, producer, musician',
#   'Spouse': 'Clayton Verbinski',
#   'Years active': '1989–present'},
#  {'Awards': 'Full list',
#   'Current Age': 64,
#   'Director Name': 'Kenneth Branagh',
#   'Occupations': 'Actor, filmmaker',
#   'Years active': '1981–present'},
#  {'Current Age': 83,
#   'Director Name': 'Hayao Miyazaki',
#   'Occupations': 'Animator, filmmaker, screenwriter, author, manga artist',
#   'Spouse': 'Akemi Ōta',
#   'Years active': '1963–present'},
#  {'Current Age': 80,
#   'Director Name': 'John Pasquin',
#   'Spouse': 'JoBeth Williams',
#   'Years active': '1982–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2019)',
#   'Current Age': 45,
#   'Director Name': 'Josh Cooley',
#   'Occupations': 'Film director, screenwriter, storyboard artist, voice actor',
#   'Years active': '2003–present'},
#  {'Current Age': 47,
#   'Director Name': 'Peter Sohn',
#   'Occupations': 'Filmmaker, animator, storyboard artist, voice actor',
#   'Spouse': 'Anna Chambers',
#   'Years active': '1995–present'},
#  {'Current Age': 66,
#   'Director Name': 'Barry Cook',
#   'Occupations': 'Film director, writer, effects animator',
#   'Years active': '1982–present'},
#  {'Current Age': 51,
#   'Director Name': 'Hiromasa Yonebayashi',
#   'Years active': '1996–present'},
#  {'Current Age': 51,
#   'Director Name': 'Nitesh Tiwari',
#   'Spouse': 'Ashwiny Iyer',
#   'Years active': '2011–present'},
#  {'Current Age': 97, 'Director Name': 'Robert Butler'},
#  {'Current Age': 62,
#   'Director Name': 'Sara Sugarman',
#   'Occupations': 'Actress, filmmaker',
#   'Spouse': 'David Thewlis',
#   'Years active': '1979–present'},
#  {'Current Age': 73, 'Director Name': 'Paul and Gaëtan Brizzi'},
#  {'Current Age': 61,
#   'Director Name': 'Brian Henson',
#   'Occupations': 'Puppeteer, director, producer, voice actor, chairman of, The '
#                  'Jim Henson Company',
#   'Years active': '1979–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2009), (2015), (2020)',
#   'Current Age': 56,
#   'Director Name': 'Pete Docter',
#   'Occupations': 'Film director, screenwriter, producer, animator, voice actor',
#   'Spouse': 'Amanda Docter',
#   'Years active': '1985–present'},
#  {'Current Age': 107,
#   'Director Name': 'Don Chaffey',
#   'Occupations': 'Film director, writer, film producer, art director',
#   'Years active': '1948–1989'},
#  {'Current Age': 79, 'Director Name': 'Bob Spiers'},
#  {'Current Age': 136,
#   'Director Name': 'Ford Beebe',
#   'Years active': '1916–1977'},
#  {'Current Age': 77,
#   'Director Name': 'Tim Hunter',
#   'Years active': '1979–present'},
#  {'Current Age': 54,
#   'Director Name': 'Charlie Bean',
#   'Occupations': 'Filmmaker, animator, writer, director, storyboard artist, '
#                  'voice actor',
#   'Years active': '1990–present'},
#  {'Current Age': 60,
#   'Director Name': 'Mark Waters',
#   'Occupations': 'Director, producer',
#   'Years active': '1997–present'},
#  {'Current Age': 96,
#   'Director Name': 'Bruce Bilson',
#   'Years active': '1955–2006'},
#  {'Current Age': 75,
#   'Director Name': 'Nancy Meyers',
#   'Spouse': 'Charles Shyer',
#   'Years active': '1980–present'},
#  {'Current Age': 69,
#   'Director Name': 'Bill Paxton',
#   'Occupations': 'Actor, filmmaker, musician',
#   'Years active': '1975–2017'},
#  {'Awards': 'Padma Bhushan, (2012)',
#   'Current Age': 67,
#   'Director Name': 'Mira Nair',
#   'Occupations': 'Film director, Film producer',
#   'Years active': '1986–present'},
#  {'Current Age': 78,
#   'Director Name': 'Andrew Davis',
#   'Years active': '1969–present'},
#  {'Current Age': 85, 'Director Name': 'Joe Camp'},
#  {'Awards': 'Army Air Force Pilot Badge, Air Force Presidential Unit Citation, '
#             'American Campaign Medal, Asiatic–Pacific Campaign Medal, World '
#             'War II Victory Medal, Philippine Presidential Unit Citation',
#   'Current Age': 99,
#   'Director Name': 'Robert Altman',
#   'Years active': '1947–2006'},
#  {'Current Age': 72, 'Director Name': 'George Scribner'},
#  {'Awards': 'Best Writing, Original Story, 1940',
#   'Current Age': 126,
#   'Director Name': 'Lewis R. Foster',
#   'Spouse': 'Dorothy Wilson'},
#  {'Current Age': 42,
#   'Director Name': 'Julia Hart',
#   'Occupations': 'Filmmaker, actress, philanthropist',
#   'Spouse': 'Jordan Horowitz',
#   'Years active': '2002, 2014–present'},
#  {'Current Age': 73, 'Director Name': 'Steve Miner'},
#  {'Current Age': 71,
#   'Director Name': 'Ron Underwood',
#   'Spouse': 'Sandy Underwood',
#   'Years active': '1980–present'},
#  {'Current Age': 62,
#   'Director Name': 'Jim Fall',
#   'Years active': '1999–present'},
#  {'Awards': 'Directors Guild of America Award for Outstanding Directing – '
#             'Feature Film, (2002)',
#   'Current Age': 64,
#   'Director Name': 'Rob Marshall',
#   'Occupations': 'Film director, film producer, theater director, '
#                  'choreographer'},
#  {'Current Age': 96,
#   'Director Name': "Michael O'Herlihy",
#   'Spouse': 'Elizabeth Ryan'},
#  {'Current Age': 122, 'Director Name': 'Norm Ferguson', 'Spouse': 'Gladys F.'},
#  {'Current Age': 35,
#   'Director Name': 'Domee Shi',
#   'Occupations': 'Film director, screenwriter',
#   'Years active': '2010−present'},
#  {'Current Age': None,
#   'Director Name': 'Ralph Zondag',
#   'Years active': '1985–present'},
#  {'Current Age': 52,
#   'Director Name': 'Jugal Hansraj',
#   'Occupations': 'Actor, author, filmmaker',
#   'Spouse': 'Jasmine Dhillon',
#   'Years active': '1983–present'},
#  {'Current Age': 87, 'Director Name': 'Steven Hilliard Stern'},
#  {'Current Age': 99,
#   'Director Name': 'Russ Mayberry',
#   'Spouse': 'Sandy Mayberry (?–2012)',
#   'Years active': '1947–1995'},
#  {'Awards': 'Hong Kong Film Awards, –, Best Action Choreography, 1996, 1997, '
#             'Golden Horse Awards, –, Best Action Choreography, 1997',
#   'Current Age': 64,
#   'Director Name': 'Stanley Tong',
#   'Occupations': 'Film director, film producer, stunt choreographer, '
#                  'screenwriter, entrepreneur, philanthropist',
#   'Years active': '1991–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2021)',
#   'Current Age': 50,
#   'Director Name': 'Jared Bush',
#   'Occupations': 'Screenwriter, producer, director',
#   'Spouse': 'Pamela McDonald',
#   'Years active': '1998–present'},
#  {'Awards': 'Academy Award for Best Adapted Screenplay, (1998)',
#   'Current Age': 69,
#   'Director Name': 'Bill Condon',
#   'Years active': '1981–present'},
#  {'Current Age': 72, 'Director Name': 'Duwayne Dunham'},
#  {'Current Age': None,
#   'Director Name': 'Arlene Sanford',
#   'Years active': '1979–present'},
#  {'Awards': 'Full list',
#   'Current Age': 43,
#   'Director Name': 'Beyoncé',
#   'Occupations': 'Singer, songwriter, businesswoman, actress, philanthropist, '
#                  '[4], producer, record executive, director',
#   'Spouse': 'Jay-Z',
#   'Years active': '1990–present'},
#  {'Current Age': 52,
#   'Director Name': 'Tony Leondis',
#   'Years active': '1997–2017'},
#  {'Awards': 'Disney Legend',
#   'Current Age': 123,
#   'Director Name': 'Clyde Geronimi'},
#  {'Current Age': 90, 'Director Name': 'Gary Nelson', 'Spouse': 'Judi Meredith'},
#  {'Current Age': 99, 'Director Name': 'N. Paul Kenworthy'},
#  {'Current Age': 116,
#   'Director Name': 'Ralph Wright',
#   'Spouse': 'Irmgard Julia Wright (died 2011) (m. 1956–1983; his death)',
#   'Years active': '1931–1983'},
#  {'Current Age': 62,
#   'Director Name': 'David Mickey Evans',
#   'Occupations': 'Film director, screenwriter',
#   'Years active': '1987–present'},
#  {'Current Age': 100, 'Director Name': 'Bernard McEveety'},
#  {'Current Age': 68,
#   'Director Name': 'John Lee Hancock',
#   'Occupations': 'Screenwriter, director, producer',
#   'Years active': '1987–present'},
#  {'Current Age': 71, 'Director Name': 'James Orr'},
#  {'Current Age': 74, 'Director Name': 'Louis Schwartzberg'},
#  {'Awards': 'Best Screenplay Award (Cannes Film Festival), 1974',
#   'Current Age': 79,
#   'Director Name': 'Matthew Robbins',
#   'Occupations': 'Screenwriter, Film director',
#   'Spouse': 'Janet Robbins',
#   'Years active': '1971–present'},
#  {'Current Age': 118,
#   'Director Name': 'Wilfred Jackson',
#   'Years active': '1928–1961'},
#  {'Current Age': None,
#   'Director Name': 'Bradley Raymond',
#   'Occupations': 'Film director, animator, storyboard artist',
#   'Years active': '1993-present'},
#  {'Current Age': 57,
#   'Director Name': 'Gorō Miyazaki',
#   'Years active': '1985–present'},
#  {'Current Age': 53,
#   'Director Name': 'Enrico Casarosa',
#   'Occupations': 'Film director, screenwriter, storyboard artist',
#   'Spouse': 'Marit Casarosa',
#   'Years active': '1996–present'},
#  {'Current Age': 78,
#   'Director Name': 'David Lynch',
#   'Occupations': 'Filmmaker, painter, visual artist, musician, actor',
#   'Years active': '1967–present'},
#  {'Current Age': 65,
#   'Director Name': 'Marc Lawrence',
#   'Occupations': 'Director, screenwriter, producer',
#   'Years active': '1984–present'},
#  {'Current Age': 81,
#   'Director Name': 'Charles Haid',
#   'Years active': '1973–present'},
#  {'Current Age': 48,
#   'Director Name': 'Dan Scanlon',
#   'Occupations': 'Film director, screenwriter, storyboard artist, animator',
#   'Spouse': 'Michele Scanlon',
#   'Years active': '1998–present'},
#  {'Current Age': 72,
#   'Director Name': 'David R. Ellis',
#   'Years active': '1975–2013'},
#  {'Current Age': 81,
#   'Director Name': 'Walter Murch',
#   'Occupations': 'Film editor, director, writer, sound designer',
#   'Spouse': 'Aggie Murch',
#   'Years active': '1969–present'},
#  {'Current Age': 89,
#   'Director Name': 'Burny Mattinson',
#   'Occupations': 'Storyboard artist, animator, film director, producer',
#   'Years active': '1953–2023'},
#  {'Current Age': 43,
#   'Director Name': 'Matt Danner',
#   'Occupations': 'Director, screenwriter, animator, storyboard artist, '
#                  'producer, voice actor',
#   'Years active': '1997–present'},
#  {'Current Age': 47,
#   'Director Name': 'Thomas Kail',
#   'Spouse': 'Michelle Williams'},
#  {'Current Age': 52,
#   'Director Name': 'Joachim Rønning',
#   'Spouse': 'Amanda Hearst',
#   'Years active': '1997–present'},
#  {'Current Age': 56,
#   'Director Name': 'Byron Howard',
#   'Occupations': 'Animator, character designer, story artist, film director, '
#                  'film producer, screenwriter'},
#  {'Current Age': 53,
#   'Director Name': 'Angela Robinson',
#   'Years active': '1995–present'},
#  {'Current Age': 56, 'Director Name': 'Aaron Blaise'},
#  {'Current Age': 70,
#   'Director Name': 'Ken Olin',
#   'Occupations': 'Actor, director, producer',
#   'Spouse': 'Patricia Wettig',
#   'Years active': '1976–present'},
#  {'Awards': 'Golden Globe Award for Best Director',
#   'Current Age': 97,
#   'Director Name': 'Charles Jarrott',
#   'Spouse': 'Katharine Blake',
#   'Years active': '1954–2002'},
#  {'Current Age': 104,
#   'Director Name': 'Andrew V. McLaglen',
#   'Years active': '1945-1991'},
#  {'Current Age': 58,
#   'Director Name': 'Roger Kumble',
#   'Spouse': 'Mary Mehagian',
#   'Years active': '1994–present'},
#  {'Current Age': 71,
#   'Director Name': 'Charles Martin Smith',
#   'Occupations': 'Actor, director, writer',
#   'Spouse': 'Ursula Martin',
#   'Years active': '1971–present'},
#  {'Current Age': 62,
#   'Director Name': 'Peter Hewitt',
#   'Years active': '1989–present'},
#  {'Current Age': 129,
#   'Director Name': 'Ben Sharpsteen',
#   'Years active': '1920–1980'},
#  {'Awards': 'Locarno International Film Festival, Most Entertaining Film, 1949',
#   'Current Age': 127,
#   'Director Name': 'Harold French',
#   'Years active': '1920–1936 (actor), 1937–1963 (director)'},
#  {'Current Age': None,
#   'Director Name': 'Peggy Holmes',
#   'Occupations': 'Choreographer, dancer, screenwriter, film director',
#   'Years active': '1984–present'},
#  {'Current Age': 113, 'Director Name': 'John Lounsbery'},
#  {'Current Age': 99,
#   'Director Name': 'Jerry Paris',
#   'Spouse': 'Ruth Benjamin',
#   'Years active': '1949–1986'},
#  {'Current Age': 62,
#   'Director Name': 'Robert Vince',
#   'Years active': '1988-present'},
#  {'Current Age': 72,
#   'Director Name': 'Gábor Csupó',
#   'Occupations': 'Animator, writer, director, producer, graphic designer, '
#                  'cartoonist',
#   'Years active': '1975–present'},
#  {'Current Age': 65,
#   'Director Name': 'Sam Raimi',
#   'Occupations': 'Film director, film producer, screenwriter, actor',
#   'Spouse': 'Gillian Greene',
#   'Years active': '1972–present'},
#  {'Current Age': 104,
#   'Director Name': 'Delbert Mann',
#   'Spouse': 'Ann Caroline Gillespie',
#   'Years active': '1949–1994'},
#  {'Current Age': 87,
#   'Director Name': 'Carroll Ballard',
#   'Years active': '1965–2005'},
#  {'Current Age': 62,
#   'Director Name': 'Chris Sanders',
#   'Occupations': 'Filmmaker, animator, illustrator, voice actor',
#   'Spouse': 'Jessica Steele-Sanders',
#   'Years active': '1984–present'},
#  {'Current Age': 64, 'Director Name': 'Alastair Fothergill'},
#  {'Current Age': 69, 'Director Name': 'Michael Nankin'},
#  {'Current Age': 81,
#   'Director Name': 'William Dear',
#   'Years active': '1975–2013'},
#  {'Current Age': 95,
#   'Director Name': 'Ron Kelly',
#   'Years active': '1956, - Present'},
#  {'Current Age': 72,
#   'Director Name': 'Henry Selick',
#   'Occupations': 'Filmmaker, stop motion animator',
#   'Years active': '1977–present'},
#  {'Current Age': 76,
#   'Director Name': 'Michael Lembeck',
#   'Years active': '1968–present'},
#  {'Current Age': 105,
#   'Director Name': 'Norman Tokar',
#   'Years active': '1956–1979'},
#  {'Current Age': 87,
#   'Director Name': 'Robert Totten',
#   'Years active': '1961–1990'},
#  {'Current Age': 69,
#   'Director Name': 'Hoyt Yeatman',
#   'Spouse': 'Giselle Garavini',
#   'Years active': '1977-present'},
#  {'Current Age': None,
#   'Director Name': 'James Bobin',
#   'Spouse': 'Francesca Beauman',
#   'Years active': '1998–present'},
#  {'Current Age': 66,
#   'Director Name': 'Stephen Herek',
#   'Years active': '1986–present'},
#  {'Current Age': 58,
#   'Director Name': 'Niki Caro',
#   'Occupations': 'Film director, film producer, screenwriter',
#   'Spouse': 'Andrew Lister',
#   'Years active': '1984–present'},
#  {'Current Age': 64,
#   'Director Name': 'Jay Russell',
#   'Spouse': 'Lee Cunningham (1991–present)',
#   'Years active': '1987–present'},
#  {'Current Age': 119,
#   'Director Name': 'Robert Stevenson',
#   'Years active': '1928–1976'},
#  {'Current Age': 116,
#   'Director Name': 'Jack Cutting',
#   'Years active': '1929-1975'},
#  {'Current Age': 61,
#   'Director Name': 'Kirk Wise',
#   'Years active': '1985–present'},
#  {'Current Age': None, 'Director Name': 'Leslie Iwerks'},
#  {'Awards': 'San Sebastian Festival –, Best Picture:, 2009, Golden Horse '
#             'Awards, –, Best Picture:, 2004, Golden Rooster Awards, –, Best '
#             'Picture:, 2004',
#   'Current Age': 53,
#   'Director Name': 'Lu Chuan',
#   'Spouse': 'Hu Die',
#   'Years active': '2000s-present'},
#  {'Current Age': 95,
#   'Director Name': 'Vincent McEveety',
#   'Years active': '1957–2000'},
#  {'Current Age': 58,
#   'Director Name': 'Anne Fletcher',
#   'Occupations': 'Filmmaker, dancer, actress',
#   'Years active': '1990–present'},
#  {'Awards': 'BAFTA Award for Best Direction, (1994)',
#   'Current Age': 82,
#   'Director Name': 'Mike Newell',
#   'Spouse': 'Bernice Stegers',
#   'Years active': '1963–present'},
#  {'Current Age': 119, 'Director Name': 'Francis D. Lyon'},
#  {'Current Age': 72,
#   'Director Name': 'Francis Glebas',
#   'Spouse': 'Denise Kress'},
#  {'Current Age': 60,
#   'Director Name': 'Adam Shankman',
#   'Years active': '1983–present'},
#  {'Current Age': 49,
#   'Director Name': 'Angus MacLane',
#   'Occupations': 'Animator, screenwriter, director, voice actor',
#   'Years active': '1997–present'},
#  {'Current Age': 70,
#   'Director Name': 'Mike Gabriel',
#   'Spouse': 'Tammy Gabriel',
#   'Years active': '1979–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2013)',
#   'Current Age': 53,
#   'Director Name': 'Jennifer Lee',
#   'Occupations': 'Screenwriter, director, producer',
#   'Years active': '2004–present'},
#  {'Current Age': 74,
#   'Director Name': 'Stuart Gillard',
#   'Years active': '1971–present'},
#  {'Current Age': 53,
#   'Director Name': 'Phil Johnston',
#   'Occupations': 'Screenwriter, film director, film producer, voice actor',
#   'Spouse': 'Jill Cordes',
#   'Years active': '2004–present'},
#  {'Current Age': 83,
#   'Director Name': 'Jacques Perrin',
#   'Spouse': 'Valentine Perrin',
#   'Years active': '1957–2022'},
#  {'Current Age': 72,
#   'Director Name': 'Tad Stones',
#   'Occupations': 'Animator, storyboard artist, screenwriter, producer, '
#                  'director',
#   'Years active': '1974–present'},
#  {'Current Age': 75,
#   'Director Name': 'Roger Allers',
#   'Occupations': 'Film director, writer, animator, storyboard artist, '
#                  'playwright',
#   'Spouse': 'Leslee Hackenson',
#   'Years active': '1974–present'},
#  {'Current Age': 53,
#   'Director Name': 'Espen Sandberg',
#   'Years active': '1997–present'},
#  {'Current Age': 62,
#   'Director Name': 'Stephen Sommers',
#   'Occupations': 'Film director, film producer, screenwriter',
#   'Spouse': 'Jana Sommers',
#   'Years active': '1988–present'},
#  {'Current Age': 115,
#   'Director Name': 'Roberto Gavaldón',
#   'Years active': '1941, -, 1979'},
#  {'Current Age': 68,
#   'Director Name': 'Peter Chelsom',
#   'Spouse': 'Lindsay McCracken',
#   'Years active': '1979–present'},
#  {'Current Age': 98,
#   'Director Name': 'Jerome Courtland',
#   'Occupations': 'Actor, director, producer',
#   'Years active': '1942–1993'},
#  {'Current Age': 61,
#   'Director Name': "Gavin O'Connor",
#   'Years active': '1992–present'},
#  {'Current Age': 66,
#   'Director Name': 'Tim Burton',
#   'Occupations': 'Film director, film producer, screenwriter, animator',
#   'Spouse': 'Lena Gieseke',
#   'Years active': '1971, [1], –present'},
#  {'Current Age': 56,
#   'Director Name': 'Chris Williams',
#   'Years active': '1996–present'},
#  {'Awards': 'Hollywood Walk of Fame, Motion Pictures, 1777, Vine Street, [1]',
#   'Current Age': 132,
#   'Director Name': 'William Beaudine',
#   'Spouse': 'Marguerite Fleischer',
#   'Years active': '1913–1966'},
#  {'Current Age': 57,
#   'Director Name': 'Luc Jacquet',
#   'Years active': '1993–present'},
#  {'Current Age': 117,
#   'Director Name': 'Les Clark',
#   'Years active': '1927–1975'},
#  {'Current Age': 50,
#   'Director Name': 'Joseph Kosinski',
#   'Spouse': 'Kristin Kosinski',
#   'Years active': '1999–present'},
#  {'Current Age': 125,
#   'Director Name': 'Byron Haskin',
#   'Spouse': 'Terry Gates',
#   'Years active': '1922–1968'},
#  {'Current Age': 77, 'Director Name': 'Robert Lieberman'},
#  {'Current Age': 78,
#   'Director Name': 'Randal Kleiser',
#   'Years active': '1962–present'},
#  {'Current Age': 62,
#   'Director Name': 'Kevin Lima',
#   'Occupations': 'Film director, animator, character designer, producer',
#   'Spouse': 'Brenda Chapman',
#   'Years active': '1985–present'},
#  {'Awards': 'Full list',
#   'Current Age': 78,
#   'Director Name': 'Steven Spielberg',
#   'Occupations': 'Film director, film producer, screenwriter',
#   'Years active': '1969–present'},
#  {'Current Age': 100, 'Director Name': 'Jack Couffer'},
#  {'Awards': 'Annie Award, , 1993, 2000, 2010, NCS Division Award, , 2000, '
#             'Winsor McCay Award, , 2011',
#   'Current Age': 69,
#   'Director Name': 'Eric Goldberg',
#   'Occupations': 'Animator, voice actor, film director, producer',
#   'Spouse': 'Susan Goldberg',
#   'Years active': '1977–present'},
#  {'Current Age': 83, 'Director Name': 'John Hough'},
#  {'Current Age': 73,
#   'Director Name': 'Steven Lisberger',
#   'Occupations': 'Film director, producer, screenwriter, animator',
#   'Spouse': 'Peggy Flook Lisberger',
#   'Years active': '1973–present'},
#  {'Current Age': 65,
#   'Director Name': 'Les Mayfield',
#   'Years active': '1981–2007'},
#  {'Current Age': 112,
#   'Director Name': 'James Algar',
#   'Years active': '1934–1977'},
#  {'Current Age': 61,
#   'Director Name': 'Jon Turteltaub',
#   'Spouse': 'Amy Eldon',
#   'Years active': '1989–present'},
#  {'Current Age': None,
#   'Director Name': 'Will Finn',
#   'Years active': '1979–present'},
#  {'Current Age': 70,
#   'Director Name': 'Donald Petrie',
#   'Years active': '1976–present'},
#  {'Current Age': 58,
#   'Director Name': 'Tom McCarthy',
#   'Occupations': 'Actor, director, screenwriter, producer',
#   'Years active': '1992–present'},
#  {'Current Age': None,
#   'Director Name': 'Darrell Rooney',
#   'Years active': '1978–present'},
#  {'Current Age': 54,
#   'Director Name': 'Dean DeBlois',
#   'Occupations': 'Director, screenwriter, producer, animator',
#   'Years active': '1988–present'},
#  {'Current Age': 55,
#   'Director Name': 'Marc Forster',
#   'Occupations': 'director, screenwriter, producer',
#   'Years active': '1995–present'},
#  {'Awards': 'Nominated for:, Academy Award for Best Cinematography, BAFTA '
#             'Award for Best Cinematography',
#   'Current Age': 78,
#   'Director Name': 'Dean Cundey',
#   'Occupations': 'Cinematographer, Film director',
#   'Years active': '1973–present'},
#  {'Current Age': 116,
#   'Director Name': 'Jack Donohue',
#   'Years active': '1927–80'},
#  {'Current Age': 55, 'Director Name': 'Don Hall'},
#  {'Awards': 'U.S. Dramatic Special Jury Award for Breakthrough Talent',
#   'Current Age': 41,
#   'Director Name': 'Justin Simien',
#   'Spouse': 'Rick Proctor (m. 2022)'},
#  {'Current Age': 61,
#   'Director Name': 'Rich Moore',
#   'Occupations': 'Animation director, screenwriter, voice actor',
#   'Years active': '1986–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2003), (2008)',
#   'Current Age': 59,
#   'Director Name': 'Andrew Stanton',
#   'Occupations': 'Film director, screenwriter, producer, animator, storyboard '
#                  'artist, voice actor',
#   'Spouse': 'Julie Stanton',
#   'Years active': '1981–present'},
#  {'Current Age': 52,
#   'Director Name': 'Saul Andrew Blinkoff',
#   'Years active': '1996–present'},
#  {'Current Age': None, 'Director Name': 'Shashanka Ghosh'},
#  {'Current Age': 71,
#   'Director Name': 'Phillip Borsos',
#   'Spouse': 'Beret Paulsen Borsos'},
#  {'Current Age': 60, 'Director Name': 'Brian Pimental'},
#  {'Current Age': 62,
#   'Director Name': 'Steven Brill',
#   'Occupations': 'Actor, director, screenwriter',
#   'Spouse': 'Ruthanna Hopper',
#   'Years active': '1989–present'},
#  {'Awards': 'Amanda, Best Film, 1988, Festival de Cine de Sitges, Special '
#             'Mention, 1988, British Film Institute, Sutherland Trophy, 1989, '
#             'Yubari International Fantastic Film Festival, Grand Jury Prize, '
#             '1990',
#   'Current Age': 69,
#   'Director Name': 'Nils Gaup',
#   'Years active': '1987–present'},
#  {'Current Age': 66,
#   'Director Name': 'Klay Hall',
#   'Years active': '1987–present'},
#  {'Current Age': 50,
#   'Director Name': "Remo D'Souza",
#   'Occupations': 'Choreographer, film director, producer',
#   'Spouse': "Lizelle D'Souza",
#   'Years active': '1995–present'},
#  {'Current Age': 122,
#   'Director Name': 'Harold D. Schuster',
#   'Years active': '1927 – 1966'},
#  {'Current Age': 72,
#   'Director Name': 'Steve Boyum',
#   'Years active': '1975–present'},
#  {'Current Age': 51, 'Director Name': 'Joe Nussbaum'},
#  {'Current Age': 61,
#   'Director Name': 'James Mangold',
#   'Occupations': 'Film director, screenwriter, producer',
#   'Spouse': 'Cathy Konrad',
#   'Years active': '1985–present'},
#  {'Current Age': 56,
#   'Director Name': 'Guy Ritchie',
#   'Occupations': 'Film director, producer, screenwriter, businessman',
#   'Years active': '1995–present'},
#  {'Current Age': 55, 'Director Name': 'Elliot M. Bour'},
#  {'Current Age': 61,
#   'Director Name': 'Brian Robbins',
#   'Occupations': 'Television producer, film producer, director, actor',
#   'Years active': '1982–present'},
#  {'Current Age': 114,
#   'Director Name': 'Herschel Daugherty',
#   'Years active': '1943–1975'},
#  {'Current Age': 54,
#   'Director Name': 'Anurag Basu',
#   'Occupations': 'Director, producer, screenwriter, actor, television '
#                  'presenter',
#   'Spouse': 'Tani Basu',
#   'Years active': '1995–present'},
#  {'Current Age': 75, 'Director Name': 'Randall Wallace'},
#  {'Current Age': 105,
#   'Director Name': 'Ted Berman',
#   'Spouse': 'Jacqueline Berman',
#   'Years active': '1940s–1980s'},
#  {'Current Age': 58,
#   'Director Name': 'Jon Favreau',
#   'Occupations': 'Filmmaker, actor',
#   'Spouse': 'Joya Tillem',
#   'Years active': '1988–present'},
#  {'Current Age': 36,
#   'Director Name': 'Emmanuel Adjei',
#   'Occupations': 'filmmaker, visual artist'},
#  {'Current Age': 80,
#   'Director Name': 'Xavier Koller',
#   'Years active': '1972–present'},
#  {'Current Age': 54,
#   'Director Name': 'Mike Mitchell',
#   'Occupations': 'Film director, writer, producer, actor, animator',
#   'Years active': '1993–present'},
#  {'Current Age': 113,
#   'Director Name': 'T. Hee',
#   'Spouse': 'Patti Arthur Price'},
#  {'Awards': 'Hollywood Walk of Fame, (2019), Disney Legends, (2019), Grammys, '
#             '(2021)',
#   'Current Age': 74,
#   'Director Name': 'Kenny Ortega',
#   'Occupations': 'Filmmaker, choreographer, dancer, actor, touring manager',
#   'Years active': '1970–present'},
#  {'Current Age': 72,
#   'Director Name': 'Brian Levant',
#   'Occupations': 'Film director, television director, film producer, '
#                  'television producer, screenwriter',
#   'Spouse': 'Alison Logan',
#   'Years active': '1976–present'},
#  {'Current Age': None,
#   'Director Name': 'Robert Stromberg',
#   'Years active': '1987–present'},
#  {'Current Age': 123,
#   'Director Name': 'Ub Iwerks',
#   'Spouse': 'Mildred Sarah Henderson',
#   'Years active': '1919–1971, [1]'},
#  {'Current Age': 110,
#   'Director Name': 'Ken Annakin',
#   'Spouse': 'Pauline Carter',
#   'Years active': '1941–1992'},
#  {'Current Age': 36, 'Director Name': 'Carlos López Estrada'},
#  {'Current Age': 114,
#   'Director Name': 'Winston Hibler',
#   'Spouse': 'Dottie Johnson',
#   'Years active': '1942–1976'},
#  {'Current Age': 44,
#   'Director Name': 'David Lowery',
#   'Spouse': 'Augustine Frizzell',
#   'Years active': '2000–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2004), (2007)',
#   'Current Age': 67,
#   'Director Name': 'Brad Bird',
#   'Occupations': 'Film director, screenwriter, producer, animator, voice actor',
#   'Spouse': 'Elizabeth Canney',
#   'Years active': '1979–present'},
#  {'Current Age': 52,
#   'Director Name': 'Ava DuVernay',
#   'Occupations': 'Director, producer, screenwriter, film publicist'},
#  {'Current Age': 101,
#   'Director Name': 'Peter Tewksbury',
#   'Years active': '1954–1977'},
#  {'Current Age': 97,
#   'Director Name': 'Alan Zaslove',
#   'Years active': '1943–2005'},
#  {'Current Age': 59,
#   'Director Name': 'Boaz Yakin',
#   'Spouse': "Alma Har'el",
#   'Years active': '1989-present'},
#  {'Awards': 'Academy Award, (1989, 1996), Golden Globe Award, (2007), Inkpot '
#             'Award, (2009), [4]',
#   'Current Age': 67,
#   'Director Name': 'John Lasseter',
#   'Occupations': 'Film director, producer, screenwriter, animator, voice actor',
#   'Spouse': 'Nancy Lasseter',
#   'Years active': '1978–present'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2012)',
#   'Current Age': 56,
#   'Director Name': 'Mark Andrews',
#   'Occupations': 'Film director, screenwriter, animator, storyboard artist',
#   'Years active': '1994–present'},
#  {'Current Age': 49,
#   'Director Name': 'Prakash Kovelamudi',
#   'Spouse': 'Kanika Dhillon'},
#  {'Current Age': None,
#   'Director Name': 'Richard Rich',
#   'Years active': '1972–present'},
#  {'Current Age': 66,
#   'Director Name': 'Tim Hill',
#   'Occupations': 'Director, screenwriter, producer, voice actor',
#   'Spouse': 'Veronica Alicino',
#   'Years active': '1991–present'},
#  {'Current Age': 58,
#   'Director Name': 'Frank Coraci',
#   'Years active': '1995–present'},
#  {'Current Age': 95,
#   'Director Name': 'Robert Scheerer',
#   'Occupations': 'Actor, film, and, television director, producer'},
#  {'Awards': 'Primetime Emmy Award, Christopher Award, Bodil Awards, Robert '
#             'Award',
#   'Current Age': 79,
#   'Director Name': 'Mikael Salomon',
#   'Years active': '1963–present'},
#  {'Current Age': None,
#   'Director Name': 'Chuck Sheetz',
#   'Years active': '1980–present'},
#  {'Current Age': 115,
#   'Director Name': 'Jack Kinney',
#   'Occupations': 'Animator, film producer, film director',
#   'Years active': '1931–1988'},
#  {'Current Age': 49, 'Director Name': 'Nathan Greno'},
#  {'Current Age': 127, 'Director Name': 'Harold Young'},
#  {'Current Age': 59,
#   'Director Name': 'Miguel Arteta',
#   'Years active': '1990-present'},
#  {'Current Age': 71,
#   'Director Name': 'John Musker',
#   'Occupations': 'Animator, film director, screenwriter, film producer',
#   'Spouse': 'Gale Musker',
#   'Years active': '1977–present'},
#  {'Current Age': 78,
#   'Director Name': 'Frank Marshall',
#   'Spouse': 'Kathleen Kennedy',
#   'Years active': '1968–present'},
#  {'Current Age': 66,
#   'Director Name': 'Raja Gosnell',
#   'Occupations': 'Film director, editor',
#   'Years active': '1978–present'},
#  {'Current Age': 108,
#   'Director Name': 'Richard Fleischer',
#   'Spouse': 'Mary Dickson',
#   'Years active': '1942–1993'},
#  {'Current Age': 69,
#   'Director Name': 'Don Hahn',
#   'Spouse': 'Denise Meara-Hahn (1987–present)',
#   'Years active': '1977–present'},
#  {'Awards': 'Accolades',
#   'Current Age': 72,
#   'Director Name': 'Robert Zemeckis',
#   'Occupations': 'Film director, producer, screenwriter',
#   'Years active': '1972–present'},
#  {'Current Age': 71,
#   'Director Name': 'Ron Clements',
#   'Occupations': 'Animator, film director, screenwriter, film producer',
#   'Spouse': 'Tamara Lee Glumace',
#   'Years active': '1972–present'},
#  {'Current Age': 103,
#   'Director Name': 'Jack Clayton',
#   'Years active': '1936–1992'},
#  {'Current Age': 52, 'Director Name': 'Dmitriy Dyachenko'},
#  {'Current Age': 50,
#   'Director Name': 'Jaume Collet-Serra',
#   'Occupations': 'Film director, producer',
#   'Years active': '1998–present'},
#  {'Current Age': 66,
#   'Director Name': 'Harald Sicheritz',
#   'Years active': '1980–present'},
#  {'Current Age': 121,
#   'Director Name': 'Norman Foster',
#   'Occupations': 'Director, screenwriter, actor',
#   'Years active': '1926–1976'},
#  {'Awards': 'Full list',
#   'Current Age': 70,
#   'Director Name': 'James Cameron',
#   'Occupations': 'Film director, screenwriter, producer, editor, '
#                  'philanthropist, sea explorer',
#   'Years active': '1978–present'},
#  {'Current Age': 79,
#   'Director Name': 'Michael Gottlieb',
#   'Years active': '1985–2004'},
#  {'Current Age': 109,
#   'Director Name': 'Art Stevens',
#   'Spouse': 'Penny Stevens (1939–2007)',
#   'Years active': '1939–1983'},
#  {'Current Age': 124, 'Director Name': 'David Hand'},
#  {'Awards': 'Academy Award for Best Animated Feature, (2010), (2017)',
#   'Current Age': 57,
#   'Director Name': 'Lee Unkrich',
#   'Occupations': 'Film editor, director, writer',
#   'Spouse': 'Laura Century',
#   'Years active': '1990–present'},
#  {'Current Age': 125,
#   'Director Name': 'Perce Pearce',
#   'Spouse': 'June Herrig Swan',
#   'Years active': '1916–1955'},
#  {'Current Age': 105,
#   'Director Name': 'David Swift',
#   'Occupations': 'Screenwriter, director, producer, animator, actor',
#   'Years active': '1937–1998'},
#  {'Current Age': 52, 'Director Name': 'Dmitry Dyachenko'},
#  {'Current Age': 90,
#   'Director Name': 'Garry Marshall',
#   'Occupations': 'Screenwriter, film director, producer, actor',
#   'Spouse': 'Barbara Sue Wells',
#   'Years active': '1959–2016'},
#  {'Current Age': 122,
#   'Director Name': 'Charles Barton',
#   'Occupations': 'film actor, vaudevillian, film director',
#   'Years active': '1920–1971'},
#  {'Current Age': 79, 'Director Name': 'Jeremy Kagan'},
#  {'Current Age': 59,
#   'Director Name': 'Frederik Du Chau',
#   'Years active': '1989–present'},
#  {'Current Age': None, 'Director Name': 'Steven Quale'},
#  {'Current Age': 115,
#   'Director Name': 'Wolfgang Reitherman',
#   'Spouse': 'Janie Marie McMillan',
#   'Years active': '1933–1981'}]

# %%
# Find the average running time of the movies:
average_running_time = movies_collection.aggregate([
    {"$group": {"_id": None, "averageRunningTime": {"$avg": "$Running time (int)"}}},
    {"$project": {"_id": 0, "averageRunningTime": {"$round": ["$averageRunningTime", 2]}}}
])

print(list(average_running_time))
# Out:
# [{'averageRunningTime': 95.78}]

# %%
# 1 question for lookup (movie that has director that won awards), 1 question for map
